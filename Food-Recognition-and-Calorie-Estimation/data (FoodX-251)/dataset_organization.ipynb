# %% [markdown]
# #just showcasing raw data into an organized dataset.
# #Training set shows the data organization process (ls used to display).
# #Validation set illustrates the conversion to structured data (code below).
# #Test set should remain random and untouched.

# %%
    from google.colab import drive
    drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install kaggle

# %%
! mkdir ~/.kaggle

# %%
# !cp /content/drive/MyDrive/kaggle.json ~/.kaggle/kaggle.json

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle competitions download ifood-2019-fgvc6
# Out:
# ...
# 100% 2.83G/2.84G [00:45<00:00, 77.3MB/s]
# 100% 2.84G/2.84G [00:45<00:00, 67.6MB/s]

# %%
# Check the contents of your dataset folder
# !ls /content/drive/MyDrive/Designproject/Implementation/Dataset/train_set
# Out:
# Streaming output truncated to the last 5000 lines.
# train_013200.jpg  train_037092.jpg  train_060984.jpg  train_085171.jpg	train_109402.jpg
# train_013204.jpg  train_037095.jpg  train_060986.jpg  train_085174.jpg	train_109403.jpg
# train_013206.jpg  train_037097.jpg  train_060987.jpg  train_085175.jpg	train_109405.jpg
# train_013209.jpg  train_037100.jpg  train_060990.jpg  train_085176.jpg	train_109406.jpg
# train_013211.jpg  train_037103.jpg  train_060991.jpg  train_085178.jpg	train_109409.jpg
# train_013212.jpg  train_037106.jpg  train_060992.jpg  train_085179.jpg	train_109411.jpg
# train_013214.jpg  train_037107.jpg  train_060993.jpg  train_085180.jpg	train_109415.jpg
# train_013218.jpg  train_037112.jpg  train_060996.jpg  train_085182.jpg	train_109416.jpg
# train_013219.jpg  train_037115.jpg  train_061005.jpg  train_085184.jpg	train_109418.jpg
# train_013222.jpg  train_037116.jpg  train_061006.jpg  train_085185.jpg	train_109419.jpg
# ...

# %%
import os
import pandas as pd
import shutil

# 1. Loading the class_list.txt and create a dictionary (class_dict)
class_list_path = '/content/drive/MyDrive/Designproject/Implementation/Dataset/class_list.txt'

class_dict = {}
with open(class_list_path, 'r') as file:
    for line in file:
        class_id, class_name = line.strip().split(' ', 1)  # Split at the first space
        class_dict[int(class_id)] = class_name

# 2. Loading the train labels CSV file
train_labels = pd.read_csv('/content/drive/MyDrive/Designproject/Implementation/Dataset/train_labels.csv')

# Path to the directory where the images are currently stored
train_images_dir = '/content/drive/MyDrive/Designproject/Implementation/Dataset/train_set/'

# New path where the images will be organized into folders by class
organized_train_dir = '/content/drive/MyDrive/Designproject/Implementation/Dataset/organized_train_set/'

# Created directory as it doesn't exist
if not os.path.exists(organized_train_dir):
    os.makedirs(organized_train_dir)

# 3. Iterate over the CSV file and move each image into its class-specific folder
for index, row in train_labels.iterrows():
    image_name = row['img_name']  # Name of the image file
    label = row['label']  # Numeric label

    # Get the corresponding class name from class_dict
    class_name = class_dict[label]

    # Created a directory for the class as it doesn't exist
    class_dir = os.path.join(organized_train_dir, class_name)
    if not os.path.exists(class_dir):
        os.makedirs(class_dir)

    # Move the image into the class-specific directory
    src_path = os.path.join(train_images_dir, image_name)
    dst_path = os.path.join(class_dir, image_name)

    if os.path.exists(src_path):
        shutil.move(src_path, dst_path)

print("Train images successfully organized into class-specific folders.")
# Out:
# Train images successfully organized into class-specific folders.

# %%
missing_images = []

for index, row in train_labels.iterrows():
    image_name = row['img_name']
    src_path = os.path.join(train_images_dir, image_name)

    if not os.path.exists(src_path):
        missing_images.append(image_name)

print(f"Missing images: {len(missing_images)}")
print(missing_images[:10])  # Print the first 10 missing image names
# Out:
# Missing images: 118475
# ['train_101733.jpg', 'train_101734.jpg', 'train_101735.jpg', 'train_101736.jpg', 'train_101737.jpg', 'train_101738.jpg', 'train_101739.jpg', 'train_101740.jpg', 'train_101741.jpg', 'train_101742.jpg']

# %%
import os

def get_folder_size(folder):
    total_size = 0
    for dirpath, dirnames, filenames in os.walk(folder):
        for filename in filenames:
            filepath = os.path.join(dirpath, filename)
            total_size += os.path.getsize(filepath)
    return total_size

folder_path = '/content/drive/MyDrive/Designproject/Implementation/Dataset/organized_train_set'
size_in_bytes = get_folder_size(folder_path)
size_in_mb = size_in_bytes / (1024 * 1024)  # Convert bytes to megabytes

print(f"Folder size: {size_in_mb:.2f} MB")
# Out:
# Folder size: 1010.25 MB

# %%
# Re-extract the train_set.zip
# !unzip /content/drive/MyDrive/Designproject/Implementation/Dataset/train_set.zip -d /content/drive/MyDrive/Designproject/Implementation/Dataset/train_set/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/Designproject/Implementation/Dataset/train_set/train_set/train_041974.jpg
#   inflating: /content/drive/MyDrive/Designproject/Implementation/Dataset/train_set/train_set/train_034206.jpg
#   inflating: /content/drive/MyDrive/Designproject/Implementation/Dataset/train_set/train_set/train_054163.jpg
#   inflating: /content/drive/MyDrive/Designproject/Implementation/Dataset/train_set/train_set/train_009636.jpg
#   inflating: /content/drive/MyDrive/Designproject/Implementation/Dataset/train_set/train_set/train_013213.jpg
#   inflating: /content/drive/MyDrive/Designproject/Implementation/Dataset/train_set/train_set/train_077657.jpg
#   inflating: /content/drive/MyDrive/Designproject/Implementation/Dataset/train_set/train_set/train_026194.jpg
#   inflating: /content/drive/MyDrive/Designproject/Implementation/Dataset/train_set/train_set/train_000231.jpg
# ...

# %%
# Re-extract the train_set.zip
# !unzip /content/drive/MyDrive/Designproject/Implementation/Dataset/val_set.zip -d /content/drive/MyDrive/Designproject/Implementation/Dataset/val_set/
# Out:
# unzip:  cannot find or open /content/drive/MyDrive/Designproject/Implementation/Dataset/val_set.zip, /content/drive/MyDrive/Designproject/Implementation/Dataset/val_set.zip.zip or /content/drive/MyDrive/Designproject/Implementation/Dataset/val_set.zip.ZIP.

# %%
# !ls /content/drive/MyDrive/Designproject/Implementation/Dataset
# Out:
# class_list.txt			 test_set	   train_set	   val_set
# ifood2019_sample_submission.csv  test_set.zip	   train_set.zip   val_set.zip
# sample_submission.csv		 train_labels.csv  val_labels.csv

# %%
import os

def get_folder_size(folder):
    total_size = 0
    for dirpath, dirnames, filenames in os.walk(folder):
        for filename in filenames:
            filepath = os.path.join(dirpath, filename)
            total_size += os.path.getsize(filepath)
    return total_size

folder_path = '/content/drive/MyDrive/Designproject/Implementation/Dataset/train_set'
size_in_bytes = get_folder_size(folder_path)
size_in_mb = size_in_bytes / (1024 * 1024)  # Convert bytes to megabytes

print(f"Folder size: {size_in_mb:.2f} MB")
# Out:
# Folder size: 2173.88 MB

# %%
import os
import pandas as pd
import shutil

# 1. Load the class_list.txt and create a dictionary (class_dict)
class_list_path = '/content/drive/MyDrive/Designproject/Implementation/Dataset/class_list.txt'

class_dict = {}
with open(class_list_path, 'r') as file:
    for line in file:
        class_id, class_name = line.strip().split(' ', 1)  # Split at the first space
        class_dict[int(class_id)] = class_name

# 2. Load the train labels CSV file
train_labels = pd.read_csv('/content/drive/MyDrive/Designproject/Implementation/Dataset/train_labels.csv')

# Path to the directory where the images are currently stored
train_images_dir = '/content/drive/MyDrive/Designproject/Implementation/Dataset/train_set/train_set'

# New path where the images will be organized into folders by class
organized_train_dir = '/content/drive/MyDrive/Designproject/Implementation/Dataset/organized_train_set/'

# Create the directory if it doesn't exist
if not os.path.exists(organized_train_dir):
    os.makedirs(organized_train_dir)

# 3. Iterate over the CSV file and move each image into its class-specific folder
for index, row in train_labels.iterrows():
    image_name = row['img_name']  # Name of the image file
    label = row['label']  # Numeric label

    # Get the corresponding class name from class_dict
    class_name = class_dict[label]

    # Create a directory for the class if it doesn't exist
    class_dir = os.path.join(organized_train_dir, class_name)
    if not os.path.exists(class_dir):
        os.makedirs(class_dir)

    # Move the image into the class-specific directory
    src_path = os.path.join(train_images_dir, image_name)
    dst_path = os.path.join(class_dir, image_name)

    if os.path.exists(src_path):
        shutil.move(src_path, dst_path)

print("Train images successfully organized into class-specific folders.")
# Out:
# Train images successfully organized into class-specific folders.

# %%
# !ls /content/drive/MyDrive/Designproject/Implementation/Dataset/organized_train_set
# Out:
# adobo			       coquilles_saint_jacques	ice_cream	       rock_cake
# ambrosia_food		       cottage_pie		jambalaya	       roulade
# apple_pie		       couscous			jerky		       rugulah
# applesauce		       crab_cake		kabob		       salisbury_steak
# applesauce_cake		       crab_food		kedgeree	       samosa
# apple_turnover		       crayfish_food		knish		       sashimi
# baby_back_rib		       creme_brulee		lasagna		       sauerbraten
# bacon_and_eggs		       croque_madame		limpet_food	       sauerkraut
# bacon_lettuce_tomato_sandwich  croquette		linguine	       sausage_roll
# baked_alaska		       cruller			lobster_bisque	       savarin
# baklava			       crumb_cake		lobster_food	       scallop
# barbecued_spareribs	       crumpet			lobster_roll_sandwich  scampi
# barbecued_wing		       cupcake			lobster_thermidor      schnitzel
# beef_bourguignonne	       custard			lutefisk	       scotch_egg
# beef_carpaccio		       deviled_egg		macaron		       scrambled_eggs
# ...

# %%
# !ls /content/drive/MyDrive/Designproject/Implementation/Dataset/organized_train_set/ambrosia_food/
# Out:
# train_074595.jpg  train_074713.jpg  train_074827.jpg  train_074943.jpg	train_075057.jpg
# train_074596.jpg  train_074714.jpg  train_074828.jpg  train_074944.jpg	train_075058.jpg
# train_074597.jpg  train_074715.jpg  train_074829.jpg  train_074945.jpg	train_075059.jpg
# train_074598.jpg  train_074716.jpg  train_074830.jpg  train_074946.jpg	train_075060.jpg
# train_074599.jpg  train_074717.jpg  train_074831.jpg  train_074947.jpg	train_075061.jpg
# train_074600.jpg  train_074718.jpg  train_074832.jpg  train_074948.jpg	train_075062.jpg
# train_074601.jpg  train_074719.jpg  train_074833.jpg  train_074949.jpg	train_075063.jpg
# train_074602.jpg  train_074720.jpg  train_074835.jpg  train_074950.jpg	train_075064.jpg
# train_074603.jpg  train_074721.jpg  train_074836.jpg  train_074951.jpg	train_075065.jpg
# train_074604.jpg  train_074722.jpg  train_074837.jpg  train_074952.jpg	train_075066.jpg
# train_074605.jpg  train_074723.jpg  train_074838.jpg  train_074953.jpg	train_075067.jpg
# ...

# %%
import os
import pandas as pd
import shutil

# 1. Load the class_list.txt and create a dictionary (class_dict)
class_list_path = '/content/drive/MyDrive/Designproject/Implementation/Dataset/class_list.txt'

class_dict = {}
with open(class_list_path, 'r') as file:
    for line in file:
        class_id, class_name = line.strip().split(' ', 1)  # Split at the first space
        class_dict[int(class_id)] = class_name

# 2. Load the validation labels CSV file
val_labels = pd.read_csv('/content/drive/MyDrive/Designproject/Implementation/Dataset/val_labels.csv')

# Path to the directory where the images are currently stored
val_images_dir = '/content/drive/MyDrive/Designproject/Implementation/Dataset/val_set/'

# New path where the images will be organized into folders by class
organized_val_dir = '/content/drive/MyDrive/Designproject/Implementation/Dataset/organized_val_set/'

# Create the directory if it doesn't exist
if not os.path.exists(organized_val_dir):
    os.makedirs(organized_val_dir)

# 3. Iterate over the CSV file and move each image into its class-specific folder
for index, row in val_labels.iterrows():
    image_name = row['img_name']  # Name of the image file
    label = row['label']  # Numeric label

    # Get the corresponding class name from class_dict
    class_name = class_dict[label]

    # Create a directory for the class if it doesn't exist
    class_dir = os.path.join(organized_val_dir, class_name)
    if not os.path.exists(class_dir):
        os.makedirs(class_dir)

    # Move the image into the class-specific directory
    src_path = os.path.join(val_images_dir, image_name)
    dst_path = os.path.join(class_dir, image_name)

    if os.path.exists(src_path):
        shutil.move(src_path, dst_path)

print("Validation images successfully organized into class-specific folders.")
# Out:
# Validation images successfully organized into class-specific folders.

# %% [markdown]
# Prepare Data Generators

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define parameters
image_size = (224, 224)  # Adjust the image size as needed
batch_size = 32           # Adjust the batch size as needed

# Create ImageDataGenerator for training set
train_datagen = ImageDataGenerator(rescale=1./255)  # Normalization
train_generator = train_datagen.flow_from_directory(
    '/content/drive/MyDrive/Designproject/Implementation/Dataset/organized_train_set/',
    target_size=image_size,
    batch_size=batch_size,
    class_mode='sparse'  # Use 'sparse' if labels are integers
)

# Create ImageDataGenerator for validation set
val_datagen = ImageDataGenerator(rescale=1./255)  # Normalization
val_generator = val_datagen.flow_from_directory(
    '/content/drive/MyDrive/Designproject/Implementation/Dataset/organized_val_set/',
    target_size=image_size,
    batch_size=batch_size,
    class_mode='sparse'  # Use 'sparse' if labels are integers
)

print("Data generators created.")
# Out:
# Found 118475 images belonging to 251 classes.
# Found 11994 images belonging to 251 classes.
# Data generators created.

# %% [markdown]
# testing with simple
# cnn model sample

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Build CNN model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(len(class_dict), activation='softmax')  # Output layer: number of classes
])

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

print("CNN model built and compiled.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-9c11b67315e5> in <cell line: 5>()
#      16     Dense(128, activation='relu'),
#      17     Dropout(0.5),
# ---> 18     Dense(len(class_dict), activation='softmax')  # Output layer: number of classes
#      19 ])
#      20
#
# NameError: name 'class_dict' is not defined

# %% [markdown]
# train 10 appoch

# %%
# Train the model
epochs = 2  # Adjust the number of epochs as needed

history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    validation_data=val_generator,
    validation_steps=val_generator.samples // batch_size,
    epochs=epochs
)

print("Model training complete.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-2cd523e01bd6> in <cell line: 4>()
#       2 epochs = 2  # Adjust the number of epochs as needed
#       3
# ----> 4 history = model.fit(
#       5     train_generator,
#       6     steps_per_epoch=train_generator.samples // batch_size,
#
# NameError: name 'model' is not defined

# %% [markdown]
# result

# %%
# Evaluate the model
val_loss, val_accuracy = model.evaluate(val_generator)
print(f"Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-12b661927009> in <cell line: 2>()
#       1 # Evaluate the model
# ----> 2 val_loss, val_accuracy = model.evaluate(val_generator)
#       3 print(f"Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}")
#
# NameError: name 'model' is not defined

# %% [markdown]
# visual

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.show()
