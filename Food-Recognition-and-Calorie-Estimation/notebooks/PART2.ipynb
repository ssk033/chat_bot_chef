# %% [markdown]
# lets start

# %%
# !mkdir -p /root/.config/
#INSTALL DATASET FROM PREVIOUS INSTRUCTION REFER(GITHUB/DATASET/LINK OR DATASET LINK FROM READFME.MD GOPI1603)
#https://github.com/Gopi1603/Food_Recognition_and_Calorie_Estimation_from_single_Image_Using_ViT_and_Mask_R-CNN.git

# %%
# !unzip /kaggle/working/ifood-2019-fgvc6.zip -d /kaggle/working/
# Out:
# Archive:  /kaggle/working/ifood-2019-fgvc6.zip
#   inflating: /kaggle/working/class_list.txt
#   inflating: /kaggle/working/ifood2019_sample_submission.csv
#   inflating: /kaggle/working/sample_submission.csv
#   inflating: /kaggle/working/test_set.zip
#   inflating: /kaggle/working/train_labels.csv
#   inflating: /kaggle/working/train_set.zip
#   inflating: /kaggle/working/val_labels.csv
#   inflating: /kaggle/working/val_set.zip

# %%
# !rm /kaggle/working/ifood-2019-fgvc6.zip > /dev/null 2>&1
# !unzip /kaggle/working/train_set.zip -d /kaggle/working/ > /dev/null 2>&1
# !unzip /kaggle/working/test_set.zip -d /kaggle/working/ > /dev/null 2>&1
# !unzip /kaggle/working/val_set.zip -d /kaggle/working/
# Out:
# Archive:  /kaggle/working/val_set.zip
#    creating: /kaggle/working/val_set/
#   inflating: /kaggle/working/val_set/val_005718.jpg
#   inflating: /kaggle/working/val_set/val_002822.jpg
#   inflating: /kaggle/working/val_set/val_000473.jpg
#   inflating: /kaggle/working/val_set/val_002322.jpg
#   inflating: /kaggle/working/val_set/val_002341.jpg
#   inflating: /kaggle/working/val_set/val_012047.jpg
#   inflating: /kaggle/working/val_set/val_006172.jpg
#   inflating: /kaggle/working/val_set/val_006206.jpg
#   inflating: /kaggle/working/val_set/val_005053.jpg
#   inflating: /kaggle/working/val_set/val_010076.jpg
#   inflating: /kaggle/working/val_set/val_005872.jpg
#   inflating: /kaggle/working/val_set/val_007417.jpg
#   inflating: /kaggle/working/val_set/val_009937.jpg
#   inflating: /kaggle/working/val_set/val_004665.jpg
#   inflating: /kaggle/working/val_set/val_002195.jpg
#   inflating: /kaggle/working/val_set/val_007858.jpg
#   inflating: /kaggle/working/val_set/val_004747.jpg
#   inflating: /kaggle/working/val_set/val_001325.jpg
#   inflating: /kaggle/working/val_set/val_005756.jpg
#   inflating: /kaggle/working/val_set/val_010195.jpg
#   inflating: /kaggle/working/val_set/val_000368.jpg
#   inflating: /kaggle/working/val_set/val_010113.jpg
#   inflating: /kaggle/working/val_set/val_004475.jpg
#   inflating: /kaggle/working/val_set/val_010150.jpg
#   inflating: /kaggle/working/val_set/val_006492.jpg
#   inflating: /kaggle/working/val_set/val_000235.jpg
#   inflating: /kaggle/working/val_set/val_004299.jpg
#   inflating: /kaggle/working/val_set/val_001839.jpg
#   inflating: /kaggle/working/val_set/val_011080.jpg
#   inflating: /kaggle/working/val_set/val_007042.jpg
#   inflating: /kaggle/working/val_set/val_004668.jpg
#   inflating: /kaggle/working/val_set/val_009748.jpg
#   inflating: /kaggle/working/val_set/val_002515.jpg
#   inflating: /kaggle/working/val_set/val_010769.jpg
#   inflating: /kaggle/working/val_set/val_003404.jpg
#   inflating: /kaggle/working/val_set/val_011992.jpg
#   inflating: /kaggle/working/val_set/val_005551.jpg
#   inflating: /kaggle/working/val_set/val_000709.jpg
#   inflating: /kaggle/working/val_set/val_001355.jpg
#   inflating: /kaggle/working/val_set/val_004064.jpg
#   inflating: /kaggle/working/val_set/val_011562.jpg
#   inflating: /kaggle/working/val_set/val_003273.jpg
#   inflating: /kaggle/working/val_set/val_001340.jpg
#   inflating: /kaggle/working/val_set/val_011317.jpg
#   inflating: /kaggle/working/val_set/val_010994.jpg
#   inflating: /kaggle/working/val_set/val_006805.jpg
#   inflating: /kaggle/working/val_set/val_007954.jpg
#   inflating: /kaggle/working/val_set/val_003083.jpg
#   inflating: /kaggle/working/val_set/val_002952.jpg
#   inflating: /kaggle/working/val_set/val_000887.jpg
#   inflating: /kaggle/working/val_set/val_001832.jpg
#   inflating: /kaggle/working/val_set/val_000181.jpg
#   inflating: /kaggle/working/val_set/val_003897.jpg
#   inflating: /kaggle/working/val_set/val_010979.jpg
#   inflating: /kaggle/working/val_set/val_004022.jpg
#   inflating: /kaggle/working/val_set/val_011110.jpg
#   inflating: /kaggle/working/val_set/val_011529.jpg
#   inflating: /kaggle/working/val_set/val_001687.jpg
#   inflating: /kaggle/working/val_set/val_004989.jpg
#   inflating: /kaggle/working/val_set/val_008248.jpg
#   inflating: /kaggle/working/val_set/val_006967.jpg
#   inflating: /kaggle/working/val_set/val_009071.jpg
#   inflating: /kaggle/working/val_set/val_005279.jpg
#   inflating: /kaggle/working/val_set/val_001734.jpg
#   inflating: /kaggle/working/val_set/val_002482.jpg
#   inflating: /kaggle/working/val_set/val_000091.jpg
#   inflating: /kaggle/working/val_set/val_005430.jpg
#   inflating: /kaggle/working/val_set/val_003491.jpg
#   inflating: /kaggle/working/val_set/val_011070.jpg
#   inflating: /kaggle/working/val_set/val_008231.jpg
#   inflating: /kaggle/working/val_set/val_005371.jpg
#   inflating: /kaggle/working/val_set/val_010126.jpg
#   inflating: /kaggle/working/val_set/val_001992.jpg
#   inflating: /kaggle/working/val_set/val_005121.jpg
#   inflating: /kaggle/working/val_set/val_004689.jpg
#   inflating: /kaggle/working/val_set/val_001801.jpg
#   inflating: /kaggle/working/val_set/val_007868.jpg
#   inflating: /kaggle/working/val_set/val_008655.jpg
#   inflating: /kaggle/working/val_set/val_002721.jpg
#   inflating: /kaggle/working/val_set/val_009441.jpg
#   inflating: /kaggle/working/val_set/val_008526.jpg
#   inflating: /kaggle/working/val_set/val_000510.jpg
#   inflating: /kaggle/working/val_set/val_010043.jpg
#   inflating: /kaggle/working/val_set/val_000995.jpg
#   inflating: /kaggle/working/val_set/val_001852.jpg
#   inflating: /kaggle/working/val_set/val_004659.jpg
#   inflating: /kaggle/working/val_set/val_001173.jpg
#   inflating: /kaggle/working/val_set/val_006855.jpg
#   inflating: /kaggle/working/val_set/val_007570.jpg
#   inflating: /kaggle/working/val_set/val_008288.jpg
#   inflating: /kaggle/working/val_set/val_010715.jpg
#   inflating: /kaggle/working/val_set/val_008366.jpg
#   inflating: /kaggle/working/val_set/val_003648.jpg
#   inflating: /kaggle/working/val_set/val_002602.jpg
#   inflating: /kaggle/working/val_set/val_001265.jpg
#   inflating: /kaggle/working/val_set/val_010020.jpg
#   inflating: /kaggle/working/val_set/val_003906.jpg
#   inflating: /kaggle/working/val_set/val_007694.jpg
#   inflating: /kaggle/working/val_set/val_011894.jpg
#   inflating: /kaggle/working/val_set/val_004652.jpg
#   inflating: /kaggle/working/val_set/val_005113.jpg
#   inflating: /kaggle/working/val_set/val_001391.jpg
#   inflating: /kaggle/working/val_set/val_005680.jpg
#   inflating: /kaggle/working/val_set/val_005919.jpg
#   inflating: /kaggle/working/val_set/val_005133.jpg
#   inflating: /kaggle/working/val_set/val_002468.jpg
#   inflating: /kaggle/working/val_set/val_002471.jpg
#   inflating: /kaggle/working/val_set/val_008064.jpg
#   inflating: /kaggle/working/val_set/val_002405.jpg
#   inflating: /kaggle/working/val_set/val_007040.jpg
#   inflating: /kaggle/working/val_set/val_008123.jpg
#   inflating: /kaggle/working/val_set/val_005834.jpg
#   inflating: /kaggle/working/val_set/val_007564.jpg
#   inflating: /kaggle/working/val_set/val_000072.jpg
#   inflating: /kaggle/working/val_set/val_000312.jpg
#   inflating: /kaggle/working/val_set/val_010946.jpg
#   inflating: /kaggle/working/val_set/val_008160.jpg
#   inflating: /kaggle/working/val_set/val_002883.jpg
#   inflating: /kaggle/working/val_set/val_012132.jpg
#   inflating: /kaggle/working/val_set/val_001569.jpg
#   inflating: /kaggle/working/val_set/val_002353.jpg
#   inflating: /kaggle/working/val_set/val_007447.jpg
#   inflating: /kaggle/working/val_set/val_005197.jpg
#   inflating: /kaggle/working/val_set/val_011561.jpg
#   inflating: /kaggle/working/val_set/val_010396.jpg
#   inflating: /kaggle/working/val_set/val_003209.jpg
#   inflating: /kaggle/working/val_set/val_010629.jpg
#   inflating: /kaggle/working/val_set/val_003681.jpg
#   inflating: /kaggle/working/val_set/val_005354.jpg
#   inflating: /kaggle/working/val_set/val_000642.jpg
#   inflating: /kaggle/working/val_set/val_012049.jpg
#   inflating: /kaggle/working/val_set/val_009587.jpg
#   inflating: /kaggle/working/val_set/val_006746.jpg
#   inflating: /kaggle/working/val_set/val_003682.jpg
#   inflating: /kaggle/working/val_set/val_001956.jpg
#   inflating: /kaggle/working/val_set/val_003053.jpg
#   inflating: /kaggle/working/val_set/val_004254.jpg
#   inflating: /kaggle/working/val_set/val_004416.jpg
#   inflating: /kaggle/working/val_set/val_010272.jpg
#   inflating: /kaggle/working/val_set/val_006807.jpg
#   inflating: /kaggle/working/val_set/val_007816.jpg
#   inflating: /kaggle/working/val_set/val_001125.jpg
#   inflating: /kaggle/working/val_set/val_006681.jpg
#   inflating: /kaggle/working/val_set/val_005025.jpg
#   inflating: /kaggle/working/val_set/val_004245.jpg
#   inflating: /kaggle/working/val_set/val_002908.jpg
#   inflating: /kaggle/working/val_set/val_011291.jpg
#   inflating: /kaggle/working/val_set/val_007304.jpg
#   inflating: /kaggle/working/val_set/val_011810.jpg
#   inflating: /kaggle/working/val_set/val_001327.jpg
#   inflating: /kaggle/working/val_set/val_005991.jpg
#   inflating: /kaggle/working/val_set/val_000119.jpg
#   inflating: /kaggle/working/val_set/val_002481.jpg
#   inflating: /kaggle/working/val_set/val_001348.jpg
#   inflating: /kaggle/working/val_set/val_006650.jpg
#   inflating: /kaggle/working/val_set/val_008313.jpg
#   inflating: /kaggle/working/val_set/val_009574.jpg
#   inflating: /kaggle/working/val_set/val_009325.jpg
#   inflating: /kaggle/working/val_set/val_000610.jpg
#   inflating: /kaggle/working/val_set/val_011969.jpg
#   inflating: /kaggle/working/val_set/val_009647.jpg
#   inflating: /kaggle/working/val_set/val_008877.jpg
#   inflating: /kaggle/working/val_set/val_010669.jpg
#   inflating: /kaggle/working/val_set/val_008539.jpg
#   inflating: /kaggle/working/val_set/val_002332.jpg
#   inflating: /kaggle/working/val_set/val_003602.jpg
#   inflating: /kaggle/working/val_set/val_004103.jpg
#   inflating: /kaggle/working/val_set/val_003875.jpg
#   inflating: /kaggle/working/val_set/val_007871.jpg
#   inflating: /kaggle/working/val_set/val_004148.jpg
#   inflating: /kaggle/working/val_set/val_007273.jpg
#   inflating: /kaggle/working/val_set/val_011488.jpg
#   inflating: /kaggle/working/val_set/val_005975.jpg
#   inflating: /kaggle/working/val_set/val_003759.jpg
#   inflating: /kaggle/working/val_set/val_003475.jpg
#   inflating: /kaggle/working/val_set/val_012001.jpg
#   inflating: /kaggle/working/val_set/val_005883.jpg
#   inflating: /kaggle/working/val_set/val_004033.jpg
#   inflating: /kaggle/working/val_set/val_011667.jpg
#   inflating: /kaggle/working/val_set/val_012088.jpg
#   inflating: /kaggle/working/val_set/val_002444.jpg
#   inflating: /kaggle/working/val_set/val_010098.jpg
#   inflating: /kaggle/working/val_set/val_007702.jpg
#   inflating: /kaggle/working/val_set/val_006841.jpg
#   inflating: /kaggle/working/val_set/val_004902.jpg
#   inflating: /kaggle/working/val_set/val_000108.jpg
#   inflating: /kaggle/working/val_set/val_000583.jpg
#   inflating: /kaggle/working/val_set/val_000980.jpg
#   inflating: /kaggle/working/val_set/val_002808.jpg
#   inflating: /kaggle/working/val_set/val_001203.jpg
#   inflating: /kaggle/working/val_set/val_010758.jpg
#   inflating: /kaggle/working/val_set/val_003315.jpg
#   inflating: /kaggle/working/val_set/val_010843.jpg
#   inflating: /kaggle/working/val_set/val_006887.jpg
#   inflating: /kaggle/working/val_set/val_006671.jpg
#   inflating: /kaggle/working/val_set/val_000967.jpg
#   inflating: /kaggle/working/val_set/val_006312.jpg
#   inflating: /kaggle/working/val_set/val_009705.jpg
#   inflating: /kaggle/working/val_set/val_005734.jpg
#   inflating: /kaggle/working/val_set/val_001989.jpg
#   inflating: /kaggle/working/val_set/val_002271.jpg
#   inflating: /kaggle/working/val_set/val_008591.jpg
#   inflating: /kaggle/working/val_set/val_003401.jpg
#   inflating: /kaggle/working/val_set/val_000928.jpg
#   inflating: /kaggle/working/val_set/val_001206.jpg
#   inflating: /kaggle/working/val_set/val_006591.jpg
#   inflating: /kaggle/working/val_set/val_002507.jpg
#   inflating: /kaggle/working/val_set/val_001212.jpg
#   inflating: /kaggle/working/val_set/val_004171.jpg
#   inflating: /kaggle/working/val_set/val_004792.jpg
#   inflating: /kaggle/working/val_set/val_000606.jpg
#   inflating: /kaggle/working/val_set/val_011850.jpg
#   inflating: /kaggle/working/val_set/val_003063.jpg
#   inflating: /kaggle/working/val_set/val_003896.jpg
#   inflating: /kaggle/working/val_set/val_011286.jpg
#   inflating: /kaggle/working/val_set/val_000806.jpg
#   inflating: /kaggle/working/val_set/val_007980.jpg
#   inflating: /kaggle/working/val_set/val_000459.jpg
#   inflating: /kaggle/working/val_set/val_009506.jpg
#   inflating: /kaggle/working/val_set/val_011466.jpg
#   inflating: /kaggle/working/val_set/val_007203.jpg
#   inflating: /kaggle/working/val_set/val_002826.jpg
#   inflating: /kaggle/working/val_set/val_000558.jpg
#   inflating: /kaggle/working/val_set/val_007723.jpg
#   inflating: /kaggle/working/val_set/val_004935.jpg
#   inflating: /kaggle/working/val_set/val_001903.jpg
#   inflating: /kaggle/working/val_set/val_007319.jpg
#   inflating: /kaggle/working/val_set/val_010160.jpg
#   inflating: /kaggle/working/val_set/val_005514.jpg
#   inflating: /kaggle/working/val_set/val_008463.jpg
#   inflating: /kaggle/working/val_set/val_005557.jpg
#   inflating: /kaggle/working/val_set/val_010036.jpg
#   inflating: /kaggle/working/val_set/val_005431.jpg
#   inflating: /kaggle/working/val_set/val_011151.jpg
#   inflating: /kaggle/working/val_set/val_004995.jpg
#   inflating: /kaggle/working/val_set/val_009497.jpg
#   inflating: /kaggle/working/val_set/val_009824.jpg
#   inflating: /kaggle/working/val_set/val_005544.jpg
#   inflating: /kaggle/working/val_set/val_001991.jpg
#   inflating: /kaggle/working/val_set/val_002801.jpg
#   inflating: /kaggle/working/val_set/val_000394.jpg
#   inflating: /kaggle/working/val_set/val_001236.jpg
#   inflating: /kaggle/working/val_set/val_012025.jpg
#   inflating: /kaggle/working/val_set/val_010990.jpg
#   inflating: /kaggle/working/val_set/val_000353.jpg
#   inflating: /kaggle/working/val_set/val_000213.jpg
#   inflating: /kaggle/working/val_set/val_009053.jpg
#   inflating: /kaggle/working/val_set/val_012022.jpg
#   inflating: /kaggle/working/val_set/val_000613.jpg
#   inflating: /kaggle/working/val_set/val_010856.jpg
#   inflating: /kaggle/working/val_set/val_004789.jpg
#   inflating: /kaggle/working/val_set/val_005473.jpg
#   inflating: /kaggle/working/val_set/val_003260.jpg
#   inflating: /kaggle/working/val_set/val_001660.jpg
#   inflating: /kaggle/working/val_set/val_007696.jpg
#   inflating: /kaggle/working/val_set/val_005558.jpg
#   inflating: /kaggle/working/val_set/val_008420.jpg
#   inflating: /kaggle/working/val_set/val_010407.jpg
#   inflating: /kaggle/working/val_set/val_001395.jpg
#   inflating: /kaggle/working/val_set/val_008472.jpg
#   inflating: /kaggle/working/val_set/val_010021.jpg
#   inflating: /kaggle/working/val_set/val_010662.jpg
#   inflating: /kaggle/working/val_set/val_003303.jpg
#   inflating: /kaggle/working/val_set/val_003719.jpg
#   inflating: /kaggle/working/val_set/val_007222.jpg
#   inflating: /kaggle/working/val_set/val_001845.jpg
#   inflating: /kaggle/working/val_set/val_009004.jpg
#   inflating: /kaggle/working/val_set/val_005008.jpg
#   inflating: /kaggle/working/val_set/val_006739.jpg
#   inflating: /kaggle/working/val_set/val_006238.jpg
#   inflating: /kaggle/working/val_set/val_006876.jpg
#   inflating: /kaggle/working/val_set/val_003534.jpg
#   inflating: /kaggle/working/val_set/val_003434.jpg
#   inflating: /kaggle/working/val_set/val_008789.jpg
#   inflating: /kaggle/working/val_set/val_010425.jpg
#   inflating: /kaggle/working/val_set/val_001180.jpg
#   inflating: /kaggle/working/val_set/val_009286.jpg
#   inflating: /kaggle/working/val_set/val_011663.jpg
#   inflating: /kaggle/working/val_set/val_009232.jpg
#   inflating: /kaggle/working/val_set/val_005692.jpg
#   inflating: /kaggle/working/val_set/val_008244.jpg
#   inflating: /kaggle/working/val_set/val_011641.jpg
#   inflating: /kaggle/working/val_set/val_010314.jpg
#   inflating: /kaggle/working/val_set/val_007338.jpg
#   inflating: /kaggle/working/val_set/val_007034.jpg
#   inflating: /kaggle/working/val_set/val_005646.jpg
#   inflating: /kaggle/working/val_set/val_006631.jpg
#   inflating: /kaggle/working/val_set/val_011096.jpg
#   inflating: /kaggle/working/val_set/val_007509.jpg
#   inflating: /kaggle/working/val_set/val_007322.jpg
#   inflating: /kaggle/working/val_set/val_000608.jpg
#   inflating: /kaggle/working/val_set/val_010026.jpg
#   inflating: /kaggle/working/val_set/val_009022.jpg
#   inflating: /kaggle/working/val_set/val_001545.jpg
#   inflating: /kaggle/working/val_set/val_010058.jpg
#   inflating: /kaggle/working/val_set/val_008167.jpg
#   inflating: /kaggle/working/val_set/val_007212.jpg
#   inflating: /kaggle/working/val_set/val_009611.jpg
#   inflating: /kaggle/working/val_set/val_003153.jpg
#   inflating: /kaggle/working/val_set/val_003904.jpg
#   inflating: /kaggle/working/val_set/val_008087.jpg
#   inflating: /kaggle/working/val_set/val_005349.jpg
#   inflating: /kaggle/working/val_set/val_004954.jpg
#   inflating: /kaggle/working/val_set/val_006002.jpg
#   inflating: /kaggle/working/val_set/val_008095.jpg
#   inflating: /kaggle/working/val_set/val_001643.jpg
#   inflating: /kaggle/working/val_set/val_012100.jpg
#   inflating: /kaggle/working/val_set/val_000269.jpg
#   inflating: /kaggle/working/val_set/val_010576.jpg
#   inflating: /kaggle/working/val_set/val_008692.jpg
#   inflating: /kaggle/working/val_set/val_003128.jpg
#   inflating: /kaggle/working/val_set/val_001568.jpg
#   inflating: /kaggle/working/val_set/val_002505.jpg
#   inflating: /kaggle/working/val_set/val_004618.jpg
#   inflating: /kaggle/working/val_set/val_006670.jpg
#   inflating: /kaggle/working/val_set/val_006119.jpg
#   inflating: /kaggle/working/val_set/val_009710.jpg
#   inflating: /kaggle/working/val_set/val_010781.jpg
#   inflating: /kaggle/working/val_set/val_002702.jpg
#   inflating: /kaggle/working/val_set/val_004502.jpg
#   inflating: /kaggle/working/val_set/val_011086.jpg
#   inflating: /kaggle/working/val_set/val_000931.jpg
#   inflating: /kaggle/working/val_set/val_005026.jpg
#   inflating: /kaggle/working/val_set/val_001841.jpg
#   inflating: /kaggle/working/val_set/val_009320.jpg
#   inflating: /kaggle/working/val_set/val_004133.jpg
#   inflating: /kaggle/working/val_set/val_010106.jpg
#   inflating: /kaggle/working/val_set/val_011152.jpg
#   inflating: /kaggle/working/val_set/val_007272.jpg
#   inflating: /kaggle/working/val_set/val_002625.jpg
#   inflating: /kaggle/working/val_set/val_003405.jpg
#   inflating: /kaggle/working/val_set/val_007683.jpg
#   inflating: /kaggle/working/val_set/val_010833.jpg
#   inflating: /kaggle/working/val_set/val_007186.jpg
#   inflating: /kaggle/working/val_set/val_006983.jpg
#   inflating: /kaggle/working/val_set/val_001133.jpg
#   inflating: /kaggle/working/val_set/val_002223.jpg
#   inflating: /kaggle/working/val_set/val_011908.jpg
#   inflating: /kaggle/working/val_set/val_010677.jpg
#   inflating: /kaggle/working/val_set/val_000006.jpg
#   inflating: /kaggle/working/val_set/val_002834.jpg
#   inflating: /kaggle/working/val_set/val_007381.jpg
#   inflating: /kaggle/working/val_set/val_006126.jpg
#   inflating: /kaggle/working/val_set/val_005499.jpg
#   inflating: /kaggle/working/val_set/val_006185.jpg
#   inflating: /kaggle/working/val_set/val_004154.jpg
#   inflating: /kaggle/working/val_set/val_003247.jpg
#   inflating: /kaggle/working/val_set/val_005865.jpg
#   inflating: /kaggle/working/val_set/val_007343.jpg
#   inflating: /kaggle/working/val_set/val_010084.jpg
#   inflating: /kaggle/working/val_set/val_005779.jpg
#   inflating: /kaggle/working/val_set/val_008852.jpg
#   inflating: /kaggle/working/val_set/val_002303.jpg
#   inflating: /kaggle/working/val_set/val_001384.jpg
#   inflating: /kaggle/working/val_set/val_003706.jpg
#   inflating: /kaggle/working/val_set/val_011839.jpg
#   inflating: /kaggle/working/val_set/val_011731.jpg
#   inflating: /kaggle/working/val_set/val_001429.jpg
#   inflating: /kaggle/working/val_set/val_000687.jpg
#   inflating: /kaggle/working/val_set/val_000453.jpg
#   inflating: /kaggle/working/val_set/val_000249.jpg
#   inflating: /kaggle/working/val_set/val_000638.jpg
#   inflating: /kaggle/working/val_set/val_006162.jpg
#   inflating: /kaggle/working/val_set/val_006626.jpg
#   inflating: /kaggle/working/val_set/val_000423.jpg
#   inflating: /kaggle/working/val_set/val_002949.jpg
#   inflating: /kaggle/working/val_set/val_005653.jpg
#   inflating: /kaggle/working/val_set/val_010806.jpg
#   inflating: /kaggle/working/val_set/val_000180.jpg
#   inflating: /kaggle/working/val_set/val_004753.jpg
#   inflating: /kaggle/working/val_set/val_005902.jpg
#   inflating: /kaggle/working/val_set/val_009178.jpg
#   inflating: /kaggle/working/val_set/val_006231.jpg
#   inflating: /kaggle/working/val_set/val_004692.jpg
#   inflating: /kaggle/working/val_set/val_004675.jpg
#   inflating: /kaggle/working/val_set/val_001324.jpg
#   inflating: /kaggle/working/val_set/val_005942.jpg
#   inflating: /kaggle/working/val_set/val_007421.jpg
#   inflating: /kaggle/working/val_set/val_008745.jpg
#   inflating: /kaggle/working/val_set/val_005864.jpg
#   inflating: /kaggle/working/val_set/val_001631.jpg
#   inflating: /kaggle/working/val_set/val_007652.jpg
#   inflating: /kaggle/working/val_set/val_001547.jpg
#   inflating: /kaggle/working/val_set/val_009390.jpg
#   inflating: /kaggle/working/val_set/val_010256.jpg
#   inflating: /kaggle/working/val_set/val_011008.jpg
#   inflating: /kaggle/working/val_set/val_008541.jpg
#   inflating: /kaggle/working/val_set/val_004035.jpg
#   inflating: /kaggle/working/val_set/val_011049.jpg
#   inflating: /kaggle/working/val_set/val_011651.jpg
#   inflating: /kaggle/working/val_set/val_001588.jpg
#   inflating: /kaggle/working/val_set/val_009284.jpg
#   inflating: /kaggle/working/val_set/val_008909.jpg
#   inflating: /kaggle/working/val_set/val_001674.jpg
#   inflating: /kaggle/working/val_set/val_002275.jpg
#   inflating: /kaggle/working/val_set/val_010928.jpg
#   inflating: /kaggle/working/val_set/val_002621.jpg
#   inflating: /kaggle/working/val_set/val_009386.jpg
#   inflating: /kaggle/working/val_set/val_010345.jpg
#   inflating: /kaggle/working/val_set/val_005067.jpg
#   inflating: /kaggle/working/val_set/val_008621.jpg
#   inflating: /kaggle/working/val_set/val_002954.jpg
#   inflating: /kaggle/working/val_set/val_005819.jpg
#   inflating: /kaggle/working/val_set/val_009521.jpg
#   inflating: /kaggle/working/val_set/val_006596.jpg
#   inflating: /kaggle/working/val_set/val_001118.jpg
#   inflating: /kaggle/working/val_set/val_006137.jpg
#   inflating: /kaggle/working/val_set/val_010799.jpg
#   inflating: /kaggle/working/val_set/val_010961.jpg
#   inflating: /kaggle/working/val_set/val_008714.jpg
#   inflating: /kaggle/working/val_set/val_001006.jpg
#   inflating: /kaggle/working/val_set/val_005036.jpg
#   inflating: /kaggle/working/val_set/val_000405.jpg
#   inflating: /kaggle/working/val_set/val_008767.jpg
#   inflating: /kaggle/working/val_set/val_007828.jpg
#   inflating: /kaggle/working/val_set/val_008838.jpg
#   inflating: /kaggle/working/val_set/val_011702.jpg
#   inflating: /kaggle/working/val_set/val_010879.jpg
#   inflating: /kaggle/working/val_set/val_009905.jpg
#   inflating: /kaggle/working/val_set/val_001803.jpg
#   inflating: /kaggle/working/val_set/val_010362.jpg
#   inflating: /kaggle/working/val_set/val_001415.jpg
#   inflating: /kaggle/working/val_set/val_002081.jpg
#   inflating: /kaggle/working/val_set/val_001982.jpg
#   inflating: /kaggle/working/val_set/val_000550.jpg
#   inflating: /kaggle/working/val_set/val_004081.jpg
#   inflating: /kaggle/working/val_set/val_004118.jpg
#   inflating: /kaggle/working/val_set/val_004089.jpg
#   inflating: /kaggle/working/val_set/val_001875.jpg
#   inflating: /kaggle/working/val_set/val_004700.jpg
#   inflating: /kaggle/working/val_set/val_009565.jpg
#   inflating: /kaggle/working/val_set/val_004086.jpg
#   inflating: /kaggle/working/val_set/val_003190.jpg
#   inflating: /kaggle/working/val_set/val_006135.jpg
#   inflating: /kaggle/working/val_set/val_005491.jpg
#   inflating: /kaggle/working/val_set/val_009343.jpg
#   inflating: /kaggle/working/val_set/val_008075.jpg
#   inflating: /kaggle/working/val_set/val_003814.jpg
#   inflating: /kaggle/working/val_set/val_005052.jpg
#   inflating: /kaggle/working/val_set/val_007714.jpg
#   inflating: /kaggle/working/val_set/val_001835.jpg
#   inflating: /kaggle/working/val_set/val_006222.jpg
#   inflating: /kaggle/working/val_set/val_001003.jpg
#   inflating: /kaggle/working/val_set/val_008734.jpg
#   inflating: /kaggle/working/val_set/val_006374.jpg
#   inflating: /kaggle/working/val_set/val_010653.jpg
#   inflating: /kaggle/working/val_set/val_007957.jpg
#   inflating: /kaggle/working/val_set/val_009280.jpg
#   inflating: /kaggle/working/val_set/val_011261.jpg
#   inflating: /kaggle/working/val_set/val_008775.jpg
#   inflating: /kaggle/working/val_set/val_010792.jpg
#   inflating: /kaggle/working/val_set/val_010841.jpg
#   inflating: /kaggle/working/val_set/val_008553.jpg
#   inflating: /kaggle/working/val_set/val_002452.jpg
#   inflating: /kaggle/working/val_set/val_012029.jpg
#   inflating: /kaggle/working/val_set/val_010865.jpg
#   inflating: /kaggle/working/val_set/val_010643.jpg
#   inflating: /kaggle/working/val_set/val_010279.jpg
#   inflating: /kaggle/working/val_set/val_008099.jpg
#   inflating: /kaggle/working/val_set/val_004555.jpg
#   inflating: /kaggle/working/val_set/val_007009.jpg
#   inflating: /kaggle/working/val_set/val_006292.jpg
#   inflating: /kaggle/working/val_set/val_003541.jpg
#   inflating: /kaggle/working/val_set/val_011060.jpg
#   inflating: /kaggle/working/val_set/val_006518.jpg
#   inflating: /kaggle/working/val_set/val_009085.jpg
#   inflating: /kaggle/working/val_set/val_006091.jpg
#   inflating: /kaggle/working/val_set/val_000539.jpg
#   inflating: /kaggle/working/val_set/val_000997.jpg
#   inflating: /kaggle/working/val_set/val_000765.jpg
#   inflating: /kaggle/working/val_set/val_006409.jpg
#   inflating: /kaggle/working/val_set/val_005083.jpg
#   inflating: /kaggle/working/val_set/val_005495.jpg
#   inflating: /kaggle/working/val_set/val_011289.jpg
#   inflating: /kaggle/working/val_set/val_006819.jpg
#   inflating: /kaggle/working/val_set/val_004714.jpg
#   inflating: /kaggle/working/val_set/val_000432.jpg
#   inflating: /kaggle/working/val_set/val_004104.jpg
#   inflating: /kaggle/working/val_set/val_009503.jpg
#   inflating: /kaggle/working/val_set/val_007573.jpg
#   inflating: /kaggle/working/val_set/val_001889.jpg
#   inflating: /kaggle/working/val_set/val_004094.jpg
#   inflating: /kaggle/working/val_set/val_001966.jpg
#   inflating: /kaggle/working/val_set/val_006249.jpg
#   inflating: /kaggle/working/val_set/val_010246.jpg
#   inflating: /kaggle/working/val_set/val_002158.jpg
#   inflating: /kaggle/working/val_set/val_007614.jpg
#   inflating: /kaggle/working/val_set/val_002764.jpg
#   inflating: /kaggle/working/val_set/val_011494.jpg
#   inflating: /kaggle/working/val_set/val_003666.jpg
#   inflating: /kaggle/working/val_set/val_009837.jpg
#   inflating: /kaggle/working/val_set/val_000804.jpg
#   inflating: /kaggle/working/val_set/val_011869.jpg
#   inflating: /kaggle/working/val_set/val_006776.jpg
#   inflating: /kaggle/working/val_set/val_012099.jpg
#   inflating: /kaggle/working/val_set/val_011046.jpg
#   inflating: /kaggle/working/val_set/val_009876.jpg
#   inflating: /kaggle/working/val_set/val_008487.jpg
#   inflating: /kaggle/working/val_set/val_004751.jpg
#   inflating: /kaggle/working/val_set/val_006150.jpg
#   inflating: /kaggle/working/val_set/val_005096.jpg
#   inflating: /kaggle/working/val_set/val_004301.jpg
#   inflating: /kaggle/working/val_set/val_007556.jpg
#   inflating: /kaggle/working/val_set/val_005455.jpg
#   inflating: /kaggle/working/val_set/val_004942.jpg
#   inflating: /kaggle/working/val_set/val_010035.jpg
#   inflating: /kaggle/working/val_set/val_002331.jpg
#   inflating: /kaggle/working/val_set/val_005502.jpg
#   inflating: /kaggle/working/val_set/val_001362.jpg
#   inflating: /kaggle/working/val_set/val_011788.jpg
#   inflating: /kaggle/working/val_set/val_002093.jpg
#   inflating: /kaggle/working/val_set/val_004377.jpg
#   inflating: /kaggle/working/val_set/val_007692.jpg
#   inflating: /kaggle/working/val_set/val_002058.jpg
#   inflating: /kaggle/working/val_set/val_009353.jpg
#   inflating: /kaggle/working/val_set/val_011662.jpg
#   inflating: /kaggle/working/val_set/val_006109.jpg
#   inflating: /kaggle/working/val_set/val_009218.jpg
#   inflating: /kaggle/working/val_set/val_002666.jpg
#   inflating: /kaggle/working/val_set/val_010301.jpg
#   inflating: /kaggle/working/val_set/val_005318.jpg
#   inflating: /kaggle/working/val_set/val_007523.jpg
#   inflating: /kaggle/working/val_set/val_006507.jpg
#   inflating: /kaggle/working/val_set/val_002027.jpg
#   inflating: /kaggle/working/val_set/val_007145.jpg
#   inflating: /kaggle/working/val_set/val_008602.jpg
#   inflating: /kaggle/working/val_set/val_011371.jpg
#   inflating: /kaggle/working/val_set/val_010951.jpg
#   inflating: /kaggle/working/val_set/val_012120.jpg
#   inflating: /kaggle/working/val_set/val_006114.jpg
#   inflating: /kaggle/working/val_set/val_000191.jpg
#   inflating: /kaggle/working/val_set/val_007706.jpg
#   inflating: /kaggle/working/val_set/val_004518.jpg
#   inflating: /kaggle/working/val_set/val_009888.jpg
#   inflating: /kaggle/working/val_set/val_007031.jpg
#   inflating: /kaggle/working/val_set/val_008942.jpg
#   inflating: /kaggle/working/val_set/val_004806.jpg
#   inflating: /kaggle/working/val_set/val_003842.jpg
#   inflating: /kaggle/working/val_set/val_005563.jpg
#   inflating: /kaggle/working/val_set/val_006491.jpg
#   inflating: /kaggle/working/val_set/val_005915.jpg
#   inflating: /kaggle/working/val_set/val_005492.jpg
#   inflating: /kaggle/working/val_set/val_005764.jpg
#   inflating: /kaggle/working/val_set/val_011996.jpg
#   inflating: /kaggle/working/val_set/val_005946.jpg
#   inflating: /kaggle/working/val_set/val_003337.jpg
#   inflating: /kaggle/working/val_set/val_008524.jpg
#   inflating: /kaggle/working/val_set/val_000536.jpg
#   inflating: /kaggle/working/val_set/val_008961.jpg
#   inflating: /kaggle/working/val_set/val_011666.jpg
#   inflating: /kaggle/working/val_set/val_009278.jpg
#   inflating: /kaggle/working/val_set/val_006112.jpg
#   inflating: /kaggle/working/val_set/val_000633.jpg
#   inflating: /kaggle/working/val_set/val_001919.jpg
#   inflating: /kaggle/working/val_set/val_009849.jpg
#   inflating: /kaggle/working/val_set/val_002500.jpg
#   inflating: /kaggle/working/val_set/val_007678.jpg
#   inflating: /kaggle/working/val_set/val_009062.jpg
#   inflating: /kaggle/working/val_set/val_002324.jpg
#   inflating: /kaggle/working/val_set/val_007630.jpg
#   inflating: /kaggle/working/val_set/val_009899.jpg
#   inflating: /kaggle/working/val_set/val_005207.jpg
#   inflating: /kaggle/working/val_set/val_000965.jpg
#   inflating: /kaggle/working/val_set/val_009023.jpg
#   inflating: /kaggle/working/val_set/val_006578.jpg
#   inflating: /kaggle/working/val_set/val_000772.jpg
#   inflating: /kaggle/working/val_set/val_010866.jpg
#   inflating: /kaggle/working/val_set/val_005088.jpg
#   inflating: /kaggle/working/val_set/val_002592.jpg
#   inflating: /kaggle/working/val_set/val_006023.jpg
#   inflating: /kaggle/working/val_set/val_005196.jpg
#   inflating: /kaggle/working/val_set/val_002161.jpg
#   inflating: /kaggle/working/val_set/val_004678.jpg
#   inflating: /kaggle/working/val_set/val_005468.jpg
#   inflating: /kaggle/working/val_set/val_009817.jpg
#   inflating: /kaggle/working/val_set/val_005788.jpg
#   inflating: /kaggle/working/val_set/val_005341.jpg
#   inflating: /kaggle/working/val_set/val_010073.jpg
#   inflating: /kaggle/working/val_set/val_010500.jpg
#   inflating: /kaggle/working/val_set/val_004010.jpg
#   inflating: /kaggle/working/val_set/val_004067.jpg
#   inflating: /kaggle/working/val_set/val_005237.jpg
#   inflating: /kaggle/working/val_set/val_004401.jpg
#   inflating: /kaggle/working/val_set/val_005263.jpg
#   inflating: /kaggle/working/val_set/val_009798.jpg
#   inflating: /kaggle/working/val_set/val_002160.jpg
#   inflating: /kaggle/working/val_set/val_003757.jpg
#   inflating: /kaggle/working/val_set/val_005486.jpg
#   inflating: /kaggle/working/val_set/val_007205.jpg
#   inflating: /kaggle/working/val_set/val_004872.jpg
#   inflating: /kaggle/working/val_set/val_010572.jpg
#   inflating: /kaggle/working/val_set/val_002552.jpg
#   inflating: /kaggle/working/val_set/val_004899.jpg
#   inflating: /kaggle/working/val_set/val_009285.jpg
#   inflating: /kaggle/working/val_set/val_004432.jpg
#   inflating: /kaggle/working/val_set/val_009421.jpg
#   inflating: /kaggle/working/val_set/val_006148.jpg
#   inflating: /kaggle/working/val_set/val_006758.jpg
#   inflating: /kaggle/working/val_set/val_007437.jpg
#   inflating: /kaggle/working/val_set/val_009867.jpg
#   inflating: /kaggle/working/val_set/val_009909.jpg
#   inflating: /kaggle/working/val_set/val_011043.jpg
#   inflating: /kaggle/working/val_set/val_008431.jpg
#   inflating: /kaggle/working/val_set/val_004481.jpg
#   inflating: /kaggle/working/val_set/val_007329.jpg
#   inflating: /kaggle/working/val_set/val_010906.jpg
#   inflating: /kaggle/working/val_set/val_000871.jpg
#   inflating: /kaggle/working/val_set/val_011836.jpg
#   inflating: /kaggle/working/val_set/val_009843.jpg
#   inflating: /kaggle/working/val_set/val_011414.jpg
#   inflating: /kaggle/working/val_set/val_000166.jpg
#   inflating: /kaggle/working/val_set/val_011824.jpg
#   inflating: /kaggle/working/val_set/val_001394.jpg
#   inflating: /kaggle/working/val_set/val_005145.jpg
#   inflating: /kaggle/working/val_set/val_001054.jpg
#   inflating: /kaggle/working/val_set/val_005369.jpg
#   inflating: /kaggle/working/val_set/val_009449.jpg
#   inflating: /kaggle/working/val_set/val_005487.jpg
#   inflating: /kaggle/working/val_set/val_002129.jpg
#   inflating: /kaggle/working/val_set/val_000067.jpg
#   inflating: /kaggle/working/val_set/val_001798.jpg
#   inflating: /kaggle/working/val_set/val_010530.jpg
#   inflating: /kaggle/working/val_set/val_011653.jpg
#   inflating: /kaggle/working/val_set/val_003445.jpg
#   inflating: /kaggle/working/val_set/val_002098.jpg
#   inflating: /kaggle/working/val_set/val_003091.jpg
#   inflating: /kaggle/working/val_set/val_001405.jpg
#   inflating: /kaggle/working/val_set/val_006649.jpg
#   inflating: /kaggle/working/val_set/val_007187.jpg
#   inflating: /kaggle/working/val_set/val_011495.jpg
#   inflating: /kaggle/working/val_set/val_008120.jpg
#   inflating: /kaggle/working/val_set/val_003761.jpg
#   inflating: /kaggle/working/val_set/val_006718.jpg
#   inflating: /kaggle/working/val_set/val_006113.jpg
#   inflating: /kaggle/working/val_set/val_002979.jpg
#   inflating: /kaggle/working/val_set/val_007878.jpg
#   inflating: /kaggle/working/val_set/val_011735.jpg
#   inflating: /kaggle/working/val_set/val_004907.jpg
#   inflating: /kaggle/working/val_set/val_011592.jpg
#   inflating: /kaggle/working/val_set/val_008284.jpg
#   inflating: /kaggle/working/val_set/val_012094.jpg
#   inflating: /kaggle/working/val_set/val_006791.jpg
#   inflating: /kaggle/working/val_set/val_009886.jpg
#   inflating: /kaggle/working/val_set/val_011619.jpg
#   inflating: /kaggle/working/val_set/val_007339.jpg
#   inflating: /kaggle/working/val_set/val_003749.jpg
#   inflating: /kaggle/working/val_set/val_000041.jpg
#   inflating: /kaggle/working/val_set/val_003646.jpg
#   inflating: /kaggle/working/val_set/val_005518.jpg
#   inflating: /kaggle/working/val_set/val_008946.jpg
#   inflating: /kaggle/working/val_set/val_011972.jpg
#   inflating: /kaggle/working/val_set/val_004767.jpg
#   inflating: /kaggle/working/val_set/val_001738.jpg
#   inflating: /kaggle/working/val_set/val_004968.jpg
#   inflating: /kaggle/working/val_set/val_010563.jpg
#   inflating: /kaggle/working/val_set/val_003740.jpg
#   inflating: /kaggle/working/val_set/val_010029.jpg
#   inflating: /kaggle/working/val_set/val_006883.jpg
#   inflating: /kaggle/working/val_set/val_010615.jpg
#   inflating: /kaggle/working/val_set/val_007369.jpg
#   inflating: /kaggle/working/val_set/val_003797.jpg
#   inflating: /kaggle/working/val_set/val_008387.jpg
#   inflating: /kaggle/working/val_set/val_007753.jpg
#   inflating: /kaggle/working/val_set/val_009522.jpg
#   inflating: /kaggle/working/val_set/val_006250.jpg
#   inflating: /kaggle/working/val_set/val_001700.jpg
#   inflating: /kaggle/working/val_set/val_002385.jpg
#   inflating: /kaggle/working/val_set/val_002619.jpg
#   inflating: /kaggle/working/val_set/val_002582.jpg
#   inflating: /kaggle/working/val_set/val_007286.jpg
#   inflating: /kaggle/working/val_set/val_004521.jpg
#   inflating: /kaggle/working/val_set/val_007454.jpg
#   inflating: /kaggle/working/val_set/val_001498.jpg
#   inflating: /kaggle/working/val_set/val_004863.jpg
#   inflating: /kaggle/working/val_set/val_003137.jpg
#   inflating: /kaggle/working/val_set/val_007263.jpg
#   inflating: /kaggle/working/val_set/val_006466.jpg
#   inflating: /kaggle/working/val_set/val_010537.jpg
#   inflating: /kaggle/working/val_set/val_004097.jpg
#   inflating: /kaggle/working/val_set/val_009041.jpg
#   inflating: /kaggle/working/val_set/val_002232.jpg
#   inflating: /kaggle/working/val_set/val_008574.jpg
#   inflating: /kaggle/working/val_set/val_002483.jpg
#   inflating: /kaggle/working/val_set/val_007727.jpg
#   inflating: /kaggle/working/val_set/val_006512.jpg
#   inflating: /kaggle/working/val_set/val_005050.jpg
#   inflating: /kaggle/working/val_set/val_003622.jpg
#   inflating: /kaggle/working/val_set/val_008241.jpg
#   inflating: /kaggle/working/val_set/val_006391.jpg
#   inflating: /kaggle/working/val_set/val_002951.jpg
#   inflating: /kaggle/working/val_set/val_011633.jpg
#   inflating: /kaggle/working/val_set/val_006981.jpg
#   inflating: /kaggle/working/val_set/val_005136.jpg
#   inflating: /kaggle/working/val_set/val_005444.jpg
#   inflating: /kaggle/working/val_set/val_008915.jpg
#   inflating: /kaggle/working/val_set/val_005526.jpg
#   inflating: /kaggle/working/val_set/val_001353.jpg
#   inflating: /kaggle/working/val_set/val_000012.jpg
#   inflating: /kaggle/working/val_set/val_003609.jpg
#   inflating: /kaggle/working/val_set/val_001377.jpg
#   inflating: /kaggle/working/val_set/val_011682.jpg
#   inflating: /kaggle/working/val_set/val_003714.jpg
#   inflating: /kaggle/working/val_set/val_011266.jpg
#   inflating: /kaggle/working/val_set/val_004233.jpg
#   inflating: /kaggle/working/val_set/val_000248.jpg
#   inflating: /kaggle/working/val_set/val_003185.jpg
#   inflating: /kaggle/working/val_set/val_005742.jpg
#   inflating: /kaggle/working/val_set/val_004019.jpg
#   inflating: /kaggle/working/val_set/val_010094.jpg
#   inflating: /kaggle/working/val_set/val_008858.jpg
#   inflating: /kaggle/working/val_set/val_006521.jpg
#   inflating: /kaggle/working/val_set/val_005543.jpg
#   inflating: /kaggle/working/val_set/val_003859.jpg
#   inflating: /kaggle/working/val_set/val_004773.jpg
#   inflating: /kaggle/working/val_set/val_001650.jpg
#   inflating: /kaggle/working/val_set/val_004237.jpg
#   inflating: /kaggle/working/val_set/val_008701.jpg
#   inflating: /kaggle/working/val_set/val_002206.jpg
#   inflating: /kaggle/working/val_set/val_004240.jpg
#   inflating: /kaggle/working/val_set/val_001976.jpg
#   inflating: /kaggle/working/val_set/val_002140.jpg
#   inflating: /kaggle/working/val_set/val_008815.jpg
#   inflating: /kaggle/working/val_set/val_004850.jpg
#   inflating: /kaggle/working/val_set/val_003418.jpg
#   inflating: /kaggle/working/val_set/val_004351.jpg
#   inflating: /kaggle/working/val_set/val_010092.jpg
#   inflating: /kaggle/working/val_set/val_004836.jpg
#   inflating: /kaggle/working/val_set/val_001812.jpg
#   inflating: /kaggle/working/val_set/val_001322.jpg
#   inflating: /kaggle/working/val_set/val_010120.jpg
#   inflating: /kaggle/working/val_set/val_008620.jpg
#   inflating: /kaggle/working/val_set/val_002799.jpg
#   inflating: /kaggle/working/val_set/val_006339.jpg
#   inflating: /kaggle/working/val_set/val_011294.jpg
#   inflating: /kaggle/working/val_set/val_004209.jpg
#   inflating: /kaggle/working/val_set/val_009205.jpg
#   inflating: /kaggle/working/val_set/val_006241.jpg
#   inflating: /kaggle/working/val_set/val_005945.jpg
#   inflating: /kaggle/working/val_set/val_011577.jpg
#   inflating: /kaggle/working/val_set/val_009686.jpg
#   inflating: /kaggle/working/val_set/val_006599.jpg
#   inflating: /kaggle/working/val_set/val_002135.jpg
#   inflating: /kaggle/working/val_set/val_003940.jpg
#   inflating: /kaggle/working/val_set/val_005412.jpg
#   inflating: /kaggle/working/val_set/val_003960.jpg
#   inflating: /kaggle/working/val_set/val_005130.jpg
#   inflating: /kaggle/working/val_set/val_002349.jpg
#   inflating: /kaggle/working/val_set/val_003419.jpg
#   inflating: /kaggle/working/val_set/val_004379.jpg
#   inflating: /kaggle/working/val_set/val_003996.jpg
#   inflating: /kaggle/working/val_set/val_011121.jpg
#   inflating: /kaggle/working/val_set/val_012017.jpg
#   inflating: /kaggle/working/val_set/val_007320.jpg
#   inflating: /kaggle/working/val_set/val_004408.jpg
#   inflating: /kaggle/working/val_set/val_001423.jpg
#   inflating: /kaggle/working/val_set/val_006013.jpg
#   inflating: /kaggle/working/val_set/val_007196.jpg
#   inflating: /kaggle/working/val_set/val_002796.jpg
#   inflating: /kaggle/working/val_set/val_005497.jpg
#   inflating: /kaggle/working/val_set/val_005684.jpg
#   inflating: /kaggle/working/val_set/val_000061.jpg
#   inflating: /kaggle/working/val_set/val_008415.jpg
#   inflating: /kaggle/working/val_set/val_008842.jpg
#   inflating: /kaggle/working/val_set/val_001105.jpg
#   inflating: /kaggle/working/val_set/val_000616.jpg
#   inflating: /kaggle/working/val_set/val_003095.jpg
#   inflating: /kaggle/working/val_set/val_006823.jpg
#   inflating: /kaggle/working/val_set/val_006820.jpg
#   inflating: /kaggle/working/val_set/val_010122.jpg
#   inflating: /kaggle/working/val_set/val_011487.jpg
#   inflating: /kaggle/working/val_set/val_004641.jpg
#   inflating: /kaggle/working/val_set/val_010794.jpg
#   inflating: /kaggle/working/val_set/val_000741.jpg
#   inflating: /kaggle/working/val_set/val_002208.jpg
#   inflating: /kaggle/working/val_set/val_002196.jpg
#   inflating: /kaggle/working/val_set/val_002225.jpg
#   inflating: /kaggle/working/val_set/val_011680.jpg
#   inflating: /kaggle/working/val_set/val_004263.jpg
#   inflating: /kaggle/working/val_set/val_005761.jpg
#   inflating: /kaggle/working/val_set/val_001973.jpg
#   inflating: /kaggle/working/val_set/val_003252.jpg
#   inflating: /kaggle/working/val_set/val_008476.jpg
#   inflating: /kaggle/working/val_set/val_008293.jpg
#   inflating: /kaggle/working/val_set/val_011218.jpg
#   inflating: /kaggle/working/val_set/val_010950.jpg
#   inflating: /kaggle/working/val_set/val_006392.jpg
#   inflating: /kaggle/working/val_set/val_011581.jpg
#   inflating: /kaggle/working/val_set/val_008723.jpg
#   inflating: /kaggle/working/val_set/val_003228.jpg
#   inflating: /kaggle/working/val_set/val_003013.jpg
#   inflating: /kaggle/working/val_set/val_005216.jpg
#   inflating: /kaggle/working/val_set/val_006328.jpg
#   inflating: /kaggle/working/val_set/val_008631.jpg
#   inflating: /kaggle/working/val_set/val_008093.jpg
#   inflating: /kaggle/working/val_set/val_006710.jpg
#   inflating: /kaggle/working/val_set/val_004992.jpg
#   inflating: /kaggle/working/val_set/val_003937.jpg
#   inflating: /kaggle/working/val_set/val_004955.jpg
#   inflating: /kaggle/working/val_set/val_008124.jpg
#   inflating: /kaggle/working/val_set/val_007330.jpg
#   inflating: /kaggle/working/val_set/val_004990.jpg
#   inflating: /kaggle/working/val_set/val_010510.jpg
#   inflating: /kaggle/working/val_set/val_000489.jpg
#   inflating: /kaggle/working/val_set/val_006569.jpg
#   inflating: /kaggle/working/val_set/val_005465.jpg
#   inflating: /kaggle/working/val_set/val_005060.jpg
#   inflating: /kaggle/working/val_set/val_006302.jpg
#   inflating: /kaggle/working/val_set/val_006308.jpg
#   inflating: /kaggle/working/val_set/val_009517.jpg
#   inflating: /kaggle/working/val_set/val_001555.jpg
#   inflating: /kaggle/working/val_set/val_006554.jpg
#   inflating: /kaggle/working/val_set/val_001987.jpg
#   inflating: /kaggle/working/val_set/val_003502.jpg
#   inflating: /kaggle/working/val_set/val_000532.jpg
#   inflating: /kaggle/working/val_set/val_003732.jpg
#   inflating: /kaggle/working/val_set/val_009277.jpg
#   inflating: /kaggle/working/val_set/val_005327.jpg
#   inflating: /kaggle/working/val_set/val_007522.jpg
#   inflating: /kaggle/working/val_set/val_001790.jpg
#   inflating: /kaggle/working/val_set/val_007216.jpg
#   inflating: /kaggle/working/val_set/val_009942.jpg
#   inflating: /kaggle/working/val_set/val_005440.jpg
#   inflating: /kaggle/working/val_set/val_004996.jpg
#   inflating: /kaggle/working/val_set/val_003729.jpg
#   inflating: /kaggle/working/val_set/val_003945.jpg
#   inflating: /kaggle/working/val_set/val_007786.jpg
#   inflating: /kaggle/working/val_set/val_011402.jpg
#   inflating: /kaggle/working/val_set/val_010506.jpg
#   inflating: /kaggle/working/val_set/val_000593.jpg
#   inflating: /kaggle/working/val_set/val_005823.jpg
#   inflating: /kaggle/working/val_set/val_011095.jpg
#   inflating: /kaggle/working/val_set/val_005266.jpg
#   inflating: /kaggle/working/val_set/val_007892.jpg
#   inflating: /kaggle/working/val_set/val_004622.jpg
#   inflating: /kaggle/working/val_set/val_010206.jpg
#   inflating: /kaggle/working/val_set/val_006669.jpg
#   inflating: /kaggle/working/val_set/val_005745.jpg
#   inflating: /kaggle/working/val_set/val_011455.jpg
#   inflating: /kaggle/working/val_set/val_002871.jpg
#   inflating: /kaggle/working/val_set/val_004228.jpg
#   inflating: /kaggle/working/val_set/val_010801.jpg
#   inflating: /kaggle/working/val_set/val_002891.jpg
#   inflating: /kaggle/working/val_set/val_009166.jpg
#   inflating: /kaggle/working/val_set/val_005561.jpg
#   inflating: /kaggle/working/val_set/val_005127.jpg
#   inflating: /kaggle/working/val_set/val_001628.jpg
#   inflating: /kaggle/working/val_set/val_004358.jpg
#   inflating: /kaggle/working/val_set/val_006972.jpg
#   inflating: /kaggle/working/val_set/val_002916.jpg
#   inflating: /kaggle/working/val_set/val_007239.jpg
#   inflating: /kaggle/working/val_set/val_008068.jpg
#   inflating: /kaggle/working/val_set/val_002029.jpg
#   inflating: /kaggle/working/val_set/val_007709.jpg
#   inflating: /kaggle/working/val_set/val_005631.jpg
#   inflating: /kaggle/working/val_set/val_010855.jpg
#   inflating: /kaggle/working/val_set/val_008384.jpg
#   inflating: /kaggle/working/val_set/val_002201.jpg
#   inflating: /kaggle/working/val_set/val_000686.jpg
#   inflating: /kaggle/working/val_set/val_001087.jpg
#   inflating: /kaggle/working/val_set/val_011000.jpg
#   inflating: /kaggle/working/val_set/val_010038.jpg
#   inflating: /kaggle/working/val_set/val_003651.jpg
#   inflating: /kaggle/working/val_set/val_004343.jpg
#   inflating: /kaggle/working/val_set/val_007555.jpg
#   inflating: /kaggle/working/val_set/val_003790.jpg
#   inflating: /kaggle/working/val_set/val_007262.jpg
#   inflating: /kaggle/working/val_set/val_006530.jpg
#   inflating: /kaggle/working/val_set/val_007808.jpg
#   inflating: /kaggle/working/val_set/val_007007.jpg
#   inflating: /kaggle/working/val_set/val_007424.jpg
#   inflating: /kaggle/working/val_set/val_000410.jpg
#   inflating: /kaggle/working/val_set/val_003043.jpg
#   inflating: /kaggle/working/val_set/val_001397.jpg
#   inflating: /kaggle/working/val_set/val_004786.jpg
#   inflating: /kaggle/working/val_set/val_005614.jpg
#   inflating: /kaggle/working/val_set/val_007088.jpg
#   inflating: /kaggle/working/val_set/val_006246.jpg
#   inflating: /kaggle/working/val_set/val_007223.jpg
#   inflating: /kaggle/working/val_set/val_005397.jpg
#   inflating: /kaggle/working/val_set/val_006682.jpg
#   inflating: /kaggle/working/val_set/val_009132.jpg
#   inflating: /kaggle/working/val_set/val_008013.jpg
#   inflating: /kaggle/working/val_set/val_011303.jpg
#   inflating: /kaggle/working/val_set/val_002600.jpg
#   inflating: /kaggle/working/val_set/val_002678.jpg
#   inflating: /kaggle/working/val_set/val_007532.jpg
#   inflating: /kaggle/working/val_set/val_009202.jpg
# ...
#   inflating: /kaggle/working/val_set/val_006782.jpg
#   inflating: /kaggle/working/val_set/val_005997.jpg
#   inflating: /kaggle/working/val_set/val_004062.jpg
#   inflating: /kaggle/working/val_set/val_011588.jpg
#   inflating: /kaggle/working/val_set/val_003618.jpg
#   inflating: /kaggle/working/val_set/val_007773.jpg
#   inflating: /kaggle/working/val_set/val_007583.jpg
#   inflating: /kaggle/working/val_set/val_005338.jpg
#   inflating: /kaggle/working/val_set/val_003710.jpg
#   inflating: /kaggle/working/val_set/val_006622.jpg
#   inflating: /kaggle/working/val_set/val_010971.jpg
#   inflating: /kaggle/working/val_set/val_005156.jpg
#   inflating: /kaggle/working/val_set/val_008980.jpg
#   inflating: /kaggle/working/val_set/val_009424.jpg
#   inflating: /kaggle/working/val_set/val_004819.jpg
#   inflating: /kaggle/working/val_set/val_003781.jpg
#   inflating: /kaggle/working/val_set/val_007502.jpg
#   inflating: /kaggle/working/val_set/val_007781.jpg
#   inflating: /kaggle/working/val_set/val_003494.jpg
#   inflating: /kaggle/working/val_set/val_002841.jpg
#   inflating: /kaggle/working/val_set/val_011937.jpg
#   inflating: /kaggle/working/val_set/val_011953.jpg
#   inflating: /kaggle/working/val_set/val_000321.jpg
#   inflating: /kaggle/working/val_set/val_010292.jpg
#   inflating: /kaggle/working/val_set/val_008986.jpg
#   inflating: /kaggle/working/val_set/val_010379.jpg
#   inflating: /kaggle/working/val_set/val_007022.jpg
#   inflating: /kaggle/working/val_set/val_004527.jpg
#   inflating: /kaggle/working/val_set/val_000121.jpg
#   inflating: /kaggle/working/val_set/val_011686.jpg
#   inflating: /kaggle/working/val_set/val_004222.jpg
#   inflating: /kaggle/working/val_set/val_002492.jpg
#   inflating: /kaggle/working/val_set/val_007141.jpg
#   inflating: /kaggle/working/val_set/val_006147.jpg
#   inflating: /kaggle/working/val_set/val_009025.jpg
#   inflating: /kaggle/working/val_set/val_000049.jpg
#   inflating: /kaggle/working/val_set/val_005971.jpg
#   inflating: /kaggle/working/val_set/val_009319.jpg
#   inflating: /kaggle/working/val_set/val_003854.jpg
#   inflating: /kaggle/working/val_set/val_006036.jpg
#   inflating: /kaggle/working/val_set/val_002893.jpg
#   inflating: /kaggle/working/val_set/val_003129.jpg
#   inflating: /kaggle/working/val_set/val_003898.jpg
#   inflating: /kaggle/working/val_set/val_002050.jpg
#   inflating: /kaggle/working/val_set/val_004004.jpg
#   inflating: /kaggle/working/val_set/val_007675.jpg
#   inflating: /kaggle/working/val_set/val_002026.jpg
#   inflating: /kaggle/working/val_set/val_004495.jpg
#   inflating: /kaggle/working/val_set/val_001705.jpg
#   inflating: /kaggle/working/val_set/val_005887.jpg
#   inflating: /kaggle/working/val_set/val_011461.jpg
#   inflating: /kaggle/working/val_set/val_006204.jpg
#   inflating: /kaggle/working/val_set/val_007261.jpg
#   inflating: /kaggle/working/val_set/val_009368.jpg
#   inflating: /kaggle/working/val_set/val_009435.jpg
#   inflating: /kaggle/working/val_set/val_004128.jpg
#   inflating: /kaggle/working/val_set/val_005231.jpg
#   inflating: /kaggle/working/val_set/val_003390.jpg
#   inflating: /kaggle/working/val_set/val_007758.jpg
#   inflating: /kaggle/working/val_set/val_007408.jpg
#   inflating: /kaggle/working/val_set/val_002122.jpg
#   inflating: /kaggle/working/val_set/val_005365.jpg
#   inflating: /kaggle/working/val_set/val_001300.jpg
#   inflating: /kaggle/working/val_set/val_001205.jpg
#   inflating: /kaggle/working/val_set/val_002094.jpg
#   inflating: /kaggle/working/val_set/val_011126.jpg
#   inflating: /kaggle/working/val_set/val_008256.jpg
#   inflating: /kaggle/working/val_set/val_010885.jpg
#   inflating: /kaggle/working/val_set/val_004127.jpg
#   inflating: /kaggle/working/val_set/val_000739.jpg
#   inflating: /kaggle/working/val_set/val_004083.jpg
#   inflating: /kaggle/working/val_set/val_011145.jpg
#   inflating: /kaggle/working/val_set/val_010365.jpg
#   inflating: /kaggle/working/val_set/val_004371.jpg
#   inflating: /kaggle/working/val_set/val_006018.jpg
#   inflating: /kaggle/working/val_set/val_003785.jpg
#   inflating: /kaggle/working/val_set/val_007008.jpg
#   inflating: /kaggle/working/val_set/val_006532.jpg
#   inflating: /kaggle/working/val_set/val_007765.jpg
#   inflating: /kaggle/working/val_set/val_007321.jpg
#   inflating: /kaggle/working/val_set/val_006219.jpg
#   inflating: /kaggle/working/val_set/val_005532.jpg
#   inflating: /kaggle/working/val_set/val_008101.jpg
#   inflating: /kaggle/working/val_set/val_009568.jpg
#   inflating: /kaggle/working/val_set/val_006332.jpg
#   inflating: /kaggle/working/val_set/val_009790.jpg
#   inflating: /kaggle/working/val_set/val_002763.jpg
#   inflating: /kaggle/working/val_set/val_008705.jpg
#   inflating: /kaggle/working/val_set/val_008027.jpg
#   inflating: /kaggle/working/val_set/val_002378.jpg
#   inflating: /kaggle/working/val_set/val_007799.jpg
#   inflating: /kaggle/working/val_set/val_003701.jpg
#   inflating: /kaggle/working/val_set/val_011187.jpg
#   inflating: /kaggle/working/val_set/val_005951.jpg
#   inflating: /kaggle/working/val_set/val_007728.jpg
#   inflating: /kaggle/working/val_set/val_006078.jpg
#   inflating: /kaggle/working/val_set/val_006919.jpg
#   inflating: /kaggle/working/val_set/val_003528.jpg
#   inflating: /kaggle/working/val_set/val_004300.jpg
#   inflating: /kaggle/working/val_set/val_008773.jpg
#   inflating: /kaggle/working/val_set/val_010172.jpg
#   inflating: /kaggle/working/val_set/val_001506.jpg
#   inflating: /kaggle/working/val_set/val_011938.jpg
#   inflating: /kaggle/working/val_set/val_008213.jpg
#   inflating: /kaggle/working/val_set/val_011683.jpg
#   inflating: /kaggle/working/val_set/val_000407.jpg
#   inflating: /kaggle/working/val_set/val_010584.jpg
#   inflating: /kaggle/working/val_set/val_005099.jpg
#   inflating: /kaggle/working/val_set/val_004054.jpg
#   inflating: /kaggle/working/val_set/val_005657.jpg
#   inflating: /kaggle/working/val_set/val_005282.jpg
#   inflating: /kaggle/working/val_set/val_007336.jpg
#   inflating: /kaggle/working/val_set/val_004625.jpg
#   inflating: /kaggle/working/val_set/val_011578.jpg
#   inflating: /kaggle/working/val_set/val_007327.jpg
#   inflating: /kaggle/working/val_set/val_011372.jpg
#   inflating: /kaggle/working/val_set/val_007820.jpg
#   inflating: /kaggle/working/val_set/val_008519.jpg
#   inflating: /kaggle/working/val_set/val_010649.jpg
#   inflating: /kaggle/working/val_set/val_000872.jpg
#   inflating: /kaggle/working/val_set/val_009530.jpg
#   inflating: /kaggle/working/val_set/val_008330.jpg
#   inflating: /kaggle/working/val_set/val_003619.jpg
#   inflating: /kaggle/working/val_set/val_008601.jpg
#   inflating: /kaggle/working/val_set/val_009641.jpg
#   inflating: /kaggle/working/val_set/val_003727.jpg
#   inflating: /kaggle/working/val_set/val_008666.jpg
#   inflating: /kaggle/working/val_set/val_007429.jpg
#   inflating: /kaggle/working/val_set/val_007243.jpg
#   inflating: /kaggle/working/val_set/val_007582.jpg
#   inflating: /kaggle/working/val_set/val_009960.jpg
#   inflating: /kaggle/working/val_set/val_006198.jpg
#   inflating: /kaggle/working/val_set/val_011576.jpg
#   inflating: /kaggle/working/val_set/val_001836.jpg
#   inflating: /kaggle/working/val_set/val_010545.jpg
#   inflating: /kaggle/working/val_set/val_007596.jpg
#   inflating: /kaggle/working/val_set/val_004708.jpg
#   inflating: /kaggle/working/val_set/val_005345.jpg
#   inflating: /kaggle/working/val_set/val_006761.jpg
#   inflating: /kaggle/working/val_set/val_000794.jpg
#   inflating: /kaggle/working/val_set/val_008165.jpg
#   inflating: /kaggle/working/val_set/val_005126.jpg
#   inflating: /kaggle/working/val_set/val_001016.jpg
#   inflating: /kaggle/working/val_set/val_004874.jpg
#   inflating: /kaggle/working/val_set/val_005830.jpg
#   inflating: /kaggle/working/val_set/val_008822.jpg
#   inflating: /kaggle/working/val_set/val_001937.jpg
#   inflating: /kaggle/working/val_set/val_008067.jpg
#   inflating: /kaggle/working/val_set/val_001430.jpg
#   inflating: /kaggle/working/val_set/val_005604.jpg
#   inflating: /kaggle/working/val_set/val_007682.jpg
#   inflating: /kaggle/working/val_set/val_009578.jpg
#   inflating: /kaggle/working/val_set/val_001743.jpg
#   inflating: /kaggle/working/val_set/val_000799.jpg
#   inflating: /kaggle/working/val_set/val_005339.jpg
#   inflating: /kaggle/working/val_set/val_004224.jpg
#   inflating: /kaggle/working/val_set/val_007743.jpg
#   inflating: /kaggle/working/val_set/val_004856.jpg
#   inflating: /kaggle/working/val_set/val_005900.jpg
#   inflating: /kaggle/working/val_set/val_008894.jpg
#   inflating: /kaggle/working/val_set/val_007817.jpg
#   inflating: /kaggle/working/val_set/val_001433.jpg
#   inflating: /kaggle/working/val_set/val_001389.jpg
#   inflating: /kaggle/working/val_set/val_003369.jpg
#   inflating: /kaggle/working/val_set/val_002933.jpg
#   inflating: /kaggle/working/val_set/val_004699.jpg
#   inflating: /kaggle/working/val_set/val_001140.jpg
#   inflating: /kaggle/working/val_set/val_001380.jpg
#   inflating: /kaggle/working/val_set/val_001414.jpg
#   inflating: /kaggle/working/val_set/val_011352.jpg
#   inflating: /kaggle/working/val_set/val_006014.jpg
#   inflating: /kaggle/working/val_set/val_006944.jpg
#   inflating: /kaggle/working/val_set/val_005986.jpg
#   inflating: /kaggle/working/val_set/val_003975.jpg
#   inflating: /kaggle/working/val_set/val_006046.jpg
#   inflating: /kaggle/working/val_set/val_008993.jpg
#   inflating: /kaggle/working/val_set/val_010901.jpg
#   inflating: /kaggle/working/val_set/val_001168.jpg
#   inflating: /kaggle/working/val_set/val_002717.jpg
#   inflating: /kaggle/working/val_set/val_007142.jpg
#   inflating: /kaggle/working/val_set/val_006946.jpg
#   inflating: /kaggle/working/val_set/val_005818.jpg
#   inflating: /kaggle/working/val_set/val_011904.jpg
#   inflating: /kaggle/working/val_set/val_001090.jpg
#   inflating: /kaggle/working/val_set/val_004349.jpg
#   inflating: /kaggle/working/val_set/val_005895.jpg
#   inflating: /kaggle/working/val_set/val_010614.jpg
#   inflating: /kaggle/working/val_set/val_010909.jpg
#   inflating: /kaggle/working/val_set/val_004252.jpg
#   inflating: /kaggle/working/val_set/val_000595.jpg
#   inflating: /kaggle/working/val_set/val_010753.jpg
#   inflating: /kaggle/working/val_set/val_009006.jpg
#   inflating: /kaggle/working/val_set/val_001350.jpg
#   inflating: /kaggle/working/val_set/val_002329.jpg
#   inflating: /kaggle/working/val_set/val_010578.jpg
#   inflating: /kaggle/working/val_set/val_002506.jpg
#   inflating: /kaggle/working/val_set/val_001454.jpg
#   inflating: /kaggle/working/val_set/val_006159.jpg
#   inflating: /kaggle/working/val_set/val_011051.jpg
#   inflating: /kaggle/working/val_set/val_008930.jpg
#   inflating: /kaggle/working/val_set/val_011559.jpg
#   inflating: /kaggle/working/val_set/val_009008.jpg
#   inflating: /kaggle/working/val_set/val_002609.jpg
#   inflating: /kaggle/working/val_set/val_002501.jpg
#   inflating: /kaggle/working/val_set/val_010278.jpg
#   inflating: /kaggle/working/val_set/val_003367.jpg
#   inflating: /kaggle/working/val_set/val_010647.jpg
#   inflating: /kaggle/working/val_set/val_003689.jpg
#   inflating: /kaggle/working/val_set/val_003828.jpg
#   inflating: /kaggle/working/val_set/val_011832.jpg
#   inflating: /kaggle/working/val_set/val_007201.jpg
#   inflating: /kaggle/working/val_set/val_010115.jpg
#   inflating: /kaggle/working/val_set/val_009924.jpg
#   inflating: /kaggle/working/val_set/val_008709.jpg
#   inflating: /kaggle/working/val_set/val_002712.jpg
#   inflating: /kaggle/working/val_set/val_004291.jpg
#   inflating: /kaggle/working/val_set/val_003868.jpg
#   inflating: /kaggle/working/val_set/val_009887.jpg
#   inflating: /kaggle/working/val_set/val_003556.jpg
#   inflating: /kaggle/working/val_set/val_009156.jpg
#   inflating: /kaggle/working/val_set/val_003986.jpg
#   inflating: /kaggle/working/val_set/val_009853.jpg
#   inflating: /kaggle/working/val_set/val_001885.jpg
#   inflating: /kaggle/working/val_set/val_000889.jpg
#   inflating: /kaggle/working/val_set/val_004925.jpg
#   inflating: /kaggle/working/val_set/val_011031.jpg
#   inflating: /kaggle/working/val_set/val_010607.jpg
#   inflating: /kaggle/working/val_set/val_002769.jpg
#   inflating: /kaggle/working/val_set/val_005252.jpg
#   inflating: /kaggle/working/val_set/val_000675.jpg
#   inflating: /kaggle/working/val_set/val_009266.jpg
#   inflating: /kaggle/working/val_set/val_003120.jpg
#   inflating: /kaggle/working/val_set/val_000345.jpg
#   inflating: /kaggle/working/val_set/val_001676.jpg
#   inflating: /kaggle/working/val_set/val_005073.jpg
#   inflating: /kaggle/working/val_set/val_006273.jpg
#   inflating: /kaggle/working/val_set/val_009405.jpg
#   inflating: /kaggle/working/val_set/val_010777.jpg
#   inflating: /kaggle/working/val_set/val_008713.jpg
#   inflating: /kaggle/working/val_set/val_001933.jpg
#   inflating: /kaggle/working/val_set/val_011985.jpg
#   inflating: /kaggle/working/val_set/val_000512.jpg
#   inflating: /kaggle/working/val_set/val_005464.jpg
#   inflating: /kaggle/working/val_set/val_005923.jpg
#   inflating: /kaggle/working/val_set/val_000623.jpg
#   inflating: /kaggle/working/val_set/val_007090.jpg
#   inflating: /kaggle/working/val_set/val_009713.jpg
#   inflating: /kaggle/working/val_set/val_011505.jpg
#   inflating: /kaggle/working/val_set/val_006814.jpg
#   inflating: /kaggle/working/val_set/val_002070.jpg
#   inflating: /kaggle/working/val_set/val_007275.jpg
#   inflating: /kaggle/working/val_set/val_008268.jpg
#   inflating: /kaggle/working/val_set/val_001560.jpg
#   inflating: /kaggle/working/val_set/val_005432.jpg
#   inflating: /kaggle/working/val_set/val_009868.jpg
#   inflating: /kaggle/working/val_set/val_003798.jpg
#   inflating: /kaggle/working/val_set/val_009910.jpg
#   inflating: /kaggle/working/val_set/val_004583.jpg
#   inflating: /kaggle/working/val_set/val_004174.jpg
#   inflating: /kaggle/working/val_set/val_011582.jpg
#   inflating: /kaggle/working/val_set/val_003725.jpg
#   inflating: /kaggle/working/val_set/val_008768.jpg
#   inflating: /kaggle/working/val_set/val_007128.jpg
#   inflating: /kaggle/working/val_set/val_005303.jpg
#   inflating: /kaggle/working/val_set/val_000556.jpg
#   inflating: /kaggle/working/val_set/val_008482.jpg
#   inflating: /kaggle/working/val_set/val_001980.jpg
#   inflating: /kaggle/working/val_set/val_005874.jpg
#   inflating: /kaggle/working/val_set/val_003366.jpg
#   inflating: /kaggle/working/val_set/val_007240.jpg
#   inflating: /kaggle/working/val_set/val_004739.jpg
#   inflating: /kaggle/working/val_set/val_009628.jpg
#   inflating: /kaggle/working/val_set/val_010513.jpg
#   inflating: /kaggle/working/val_set/val_008509.jpg
#   inflating: /kaggle/working/val_set/val_010274.jpg
#   inflating: /kaggle/working/val_set/val_009810.jpg
#   inflating: /kaggle/working/val_set/val_011298.jpg
#   inflating: /kaggle/working/val_set/val_011465.jpg
#   inflating: /kaggle/working/val_set/val_010839.jpg
#   inflating: /kaggle/working/val_set/val_008436.jpg
#   inflating: /kaggle/working/val_set/val_004045.jpg
#   inflating: /kaggle/working/val_set/val_001664.jpg
#   inflating: /kaggle/working/val_set/val_002945.jpg
#   inflating: /kaggle/working/val_set/val_004457.jpg
#   inflating: /kaggle/working/val_set/val_011136.jpg
#   inflating: /kaggle/working/val_set/val_006290.jpg
#   inflating: /kaggle/working/val_set/val_012097.jpg
#   inflating: /kaggle/working/val_set/val_003251.jpg
#   inflating: /kaggle/working/val_set/val_010431.jpg
#   inflating: /kaggle/working/val_set/val_003497.jpg
#   inflating: /kaggle/working/val_set/val_000400.jpg
#   inflating: /kaggle/working/val_set/val_000171.jpg
#   inflating: /kaggle/working/val_set/val_009862.jpg
#   inflating: /kaggle/working/val_set/val_002628.jpg
#   inflating: /kaggle/working/val_set/val_002464.jpg
#   inflating: /kaggle/working/val_set/val_010468.jpg

# %%
import os
import pandas as pd
import shutil

# Paths
class_list_path = '/kaggle/working/class_list.txt'
train_labels_path = '/kaggle/working/train_labels.csv'
val_labels_path = '/kaggle/working/val_labels.csv'
train_images_dir = '/kaggle/working/train_set/'
val_images_dir = '/kaggle/working/val_set/'

# New paths for organized datasets
organized_train_dir = '/kaggle/working/organized_train_set/'
organized_val_dir = '/kaggle/working/organized_val_set/'

# 1. Load the class_list.txt and create a dictionary (class_dict)
class_dict = {}
with open(class_list_path, 'r') as file:
    for line in file:
        class_id, class_name = line.strip().split(' ', 1)  # Split at the first space
        class_dict[int(class_id)] = class_name

# Function to organize images
def organize_images(labels_path, images_dir, organized_dir):
    # Load labels CSV file
    labels = pd.read_csv(labels_path)

    # Create the directory if it doesn't exist
    if not os.path.exists(organized_dir):
        os.makedirs(organized_dir)

    # Iterate over the CSV file and move each image into its class-specific folder
    for index, row in labels.iterrows():
        image_name = row['img_name']  # Name of the image file
        label = row['label']  # Numeric label

        # Get the corresponding class name from class_dict
        class_name = class_dict[label]

        # Create a directory for the class if it doesn't exist
        class_dir = os.path.join(organized_dir, class_name)
        if not os.path.exists(class_dir):
            os.makedirs(class_dir)

        # Move the image into the class-specific directory
        src_path = os.path.join(images_dir, image_name)
        dst_path = os.path.join(class_dir, image_name)

        if os.path.exists(src_path):
            shutil.move(src_path, dst_path)

# Organize train and validation images
organize_images(train_labels_path, train_images_dir, organized_train_dir)
organize_images(val_labels_path, val_images_dir, organized_val_dir)

print("Train and validation images successfully organized into class-specific folders.")
# Out:
# Train and validation images successfully organized into class-specific folders.

# %%
# !pip install transformers datasets torch torchvision
# Out:
# Requirement already satisfied: transformers in /opt/conda/lib/python3.10/site-packages (4.45.1)
# Requirement already satisfied: datasets in /opt/conda/lib/python3.10/site-packages (3.0.1)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (2.4.0+cpu)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (0.19.0+cpu)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers) (3.15.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.25.1)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.20.0)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers) (4.66.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from datasets) (2.2.3)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets) (3.9.5)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch) (3.1.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision) (10.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)

# %%
import torch
from torch import nn, optim
from transformers import ViTForImageClassification, ViTFeatureExtractor, ViTImageProcessor
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from sklearn.metrics import accuracy_score
import os
import time
from tqdm import tqdm

# %%
# Paths to train and validation datasets
train_dir = '/kaggle/working/organized_train_set/'
val_dir = '/kaggle/working/organized_val_set/'

# Initialize feature extractor (already done)
feature_extractor = ViTImageProcessor.from_pretrained('google/vit-base-patch16-224')

# Image transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=feature_extractor.image_mean, std=feature_extractor.image_std)
])
# Out:
# preprocessor_config.json:   0%|          | 0.00/160 [00:00<?, ?B/s]

# %%
# Load datasets
train_dataset = datasets.ImageFolder(train_dir, transform=transform)
val_dataset = datasets.ImageFolder(val_dir, transform=transform)

# Create DataLoader for training and validation
train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=128, shuffle=False)

# %%
# Load the pre-trained ViT model from Hugging Face
model = ViTForImageClassification.from_pretrained(
    'google/vit-base-patch16-224',
    num_labels=251,
    ignore_mismatched_sizes=True
)

# Initialize feature extractor for ViT
feature_extractor = ViTFeatureExtractor.from_pretrained('google/vit-base-patch16-224')

# Image transformations: resize, normalize as per the ViT requirements
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=feature_extractor.image_mean, std=feature_extractor.image_std)
])
# Out:
# config.json:   0%|          | 0.00/69.7k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224 and are newly initialized because the shapes did not match:
# - classifier.bias: found shape torch.Size([1000]) in the checkpoint and torch.Size([251]) in the model instantiated
# - classifier.weight: found shape torch.Size([1000, 768]) in the checkpoint and torch.Size([251, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /opt/conda/lib/python3.10/site-packages/transformers/models/vit/feature_extraction_vit.py:28: FutureWarning: The class ViTFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use ViTImageProcessor instead.
#   warnings.warn(

# %%
# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=2e-5)

# %%
# Check if GPU is available and set device accordingly
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Move model to the device
model.to(device)

# Assume the model, criterion, optimizer, and train_loader are defined
epochs = 0
for epoch in range(epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    start_time = time.time()

    for images, labels in tqdm(train_loader, total=len(train_loader)):
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()  # Reset gradients

        # Forward pass
        outputs = model(images).logits
        loss = criterion(outputs, labels)

        # Backward pass
        loss.backward()
        optimizer.step()

        # Track accuracy
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        running_loss += loss.item()

    epoch_loss = running_loss / len(train_loader)
    epoch_acc = correct / total
    epoch_time = time.time() - start_time

    print(f'Epoch {epoch + 1}/{epochs}, Loss: {epoch_loss:.4f}, Accuracy: {epoch_acc:.4f}, Time: {epoch_time:.2f}s')

# Optionally, save the model after training
model.save_pretrained('/kaggle/working/ViT_fine_tuned_food_recognition')
# Out:
#   0%|          | 0/926 [02:19<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 27
#      24 loss = criterion(outputs, labels)
#      26 # Backward pass
# ---> 27 loss.backward()
#      28 optimizer.step()
#      30 # Track accuracy
#
# File /opt/conda/lib/python3.10/site-packages/torch/_tensor.py:521, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     511 if has_torch_function_unary(self):
#     512     return handle_torch_function(
#     513         Tensor.backward,
#     514         (self,),
#    (...)
#     519         inputs=inputs,
#     520     )
# --> 521 torch.autograd.backward(
#     522     self, gradient, retain_graph, create_graph, inputs=inputs
#     523 )
#
# File /opt/conda/lib/python3.10/site-packages/torch/autograd/__init__.py:289, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     284     retain_graph = create_graph
#     286 # The reason we repeat the same comment below is that
#     287 # some Python versions print out the first line of a multi-line function
#     288 # calls in the traceback and some print out the last line
# --> 289 _engine_run_backward(
#     290     tensors,
#     291     grad_tensors_,
#     292     retain_graph,
#     293     create_graph,
#     294     inputs,
#     295     allow_unreachable=True,
#     296     accumulate_grad=True,
#     297 )
#
# File /opt/conda/lib/python3.10/site-packages/torch/autograd/graph.py:768, in _engine_run_backward(t_outputs, *args, **kwargs)
#     766     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     767 try:
# --> 768     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     769         t_outputs, *args, **kwargs
#     770     )  # Calls into the C++ engine to run the backward pass
#     771 finally:
#     772     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
# Change to the working directory
# %cd /kaggle/working

# Create a downloadable link for your file
from IPython.display import FileLink

# Replace 'your_model.zip' with the actual file name
download_link = FileLink('ViT_fine_tuned_food_recognition.zip')
download_link
# Out:
# /kaggle/working
# /kaggle/working/ViT_fine_tuned_food_recognition.zip

# %%
# !ls /kaggle/working/
# Out:
# class_list.txt			 test_set	   val_labels.csv
# ifood2019_sample_submission.csv  test_set.zip	   val_set
# organized_train_set		 train_labels.csv  val_set.zip
# organized_val_set		 train_set
# sample_submission.csv		 train_set.zip

# %%
from transformers import ViTForImageClassification, ViTConfig
import torch

# Assuming you have a CUDA device available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Paths to your model and configuration files
model_path = "/kaggle/input/finehhh/model.safetensors"
config_path = "/kaggle/input/finehhh/config.json"

# Load the configuration
config = ViTConfig.from_json_file(config_path)

# Load the model using the local safetensors file
model = ViTForImageClassification.from_pretrained(model_path, config=config, use_safetensors=True).to(device)

# Now your model is ready to be used for inference or training

# %%
import os
from transformers import ViTForImageClassification, ViTConfig
import torch

# Set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Paths to your model and configuration files
model_path = "/kaggle/input/finehhh/model.safetensors"
config_path = "/kaggle/input/finehhh/config.json"

# Load the configuration
config = ViTConfig.from_json_file(config_path)

# Load the model using the local safetensors file
model = ViTForImageClassification.from_pretrained(
    model_path, 
    config=config, 
    use_safetensors=True
).to(device)

# Now your model is ready to be used for inference or training
print("Model loaded successfully.")
# Out:
# Model loaded successfully.

# %%
import os
from transformers import ViTForImageClassification, ViTConfig
import torch
from transformers import ViTFeatureExtractor
from PIL import Image

# Set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Paths to your model and configuration files
model_path = "/kaggle/input/finehhh/model.safetensors"
config_path = "/kaggle/input/finehhh/config.json"

# Load the configuration
config = ViTConfig.from_json_file(config_path)

# Load the model using the local safetensors file
model = ViTForImageClassification.from_pretrained(
    model_path, 
    config=config, 
    use_safetensors=True
).to(device)

print("Model loaded successfully.")

# Load feature extractor from Hugging Face
feature_extractor = ViTFeatureExtractor.from_pretrained('google/vit-base-patch16-224')

# Load and preprocess a test image
image_path = '/kaggle/working/test_set/test_000002.jpg'  # Path to your test image
image = Image.open(image_path)

# Preprocess the image
inputs = feature_extractor(images=image, return_tensors="pt").to(device)

# Perform inference
model.eval()
with torch.no_grad():
    logits = model(**inputs).logits
    predicted_class = logits.argmax(-1).item()

# Debugging: print predicted class index and number of classes
print(f"Predicted class index: {predicted_class}")
num_classes = len(class_names)  # Length of your class names list
print(f"Number of classes: {num_classes}")

# Assuming you have a list of class names
# Read class names from file or define them here
class_names = []  # Load class names here as shown in the previous steps

# Ensure the predicted class index is within the bounds
if 0 <= predicted_class < num_classes:
    predicted_class_name = class_names[predicted_class]
    print(f"Predicted food class: {predicted_class_name}")
else:
    print(f"Error: Predicted class index {predicted_class} is out of range.")
# Out:
# Model loaded successfully.
# Predicted class index: 154
# Number of classes: 4
# Error: Predicted class index 154 is out of range.

# %%
# Load class names from class_list.txt
class_list_path = "/kaggle/working/class_list.txt"  # Path to your class list

with open(class_list_path, 'r') as file:
    class_names = [line.strip() for line in file.readlines()]

print(f"Loaded class names: {class_names}")
print(f"Number of classes: {len(class_names)}")
# Out:
# Loaded class names: ['0 macaron', '1 beignet', '2 cruller', '3 cockle_food', '4 samosa', '5 tiramisu', '6 tostada', '7 moussaka', '8 dumpling', '9 sashimi', '10 knish', '11 croquette', '12 couscous', '13 porridge', '14 stuffed_cabbage', '15 seaweed_salad', '16 chow_mein', '17 rigatoni', '18 beef_tartare', '19 cannoli', '20 foie_gras', '21 cupcake', '22 osso_buco', '23 pad_thai', '24 poutine', '25 ramen', '26 pulled_pork_sandwich', '27 bibimbap', '28 chicken_kiev', '29 apple_pie', '30 risotto', '31 fruitcake', '32 chop_suey', '33 haggis', '34 scrambled_eggs', '35 frittata', '36 scampi', '37 sushi', '38 orzo', '39 fritter', '40 nacho', '41 beef_stroganoff', '42 beef_wellington', '43 spring_roll', '44 savarin', '45 crayfish_food', '46 souffle', '47 adobo', '48 streusel', '49 deviled_egg', '50 escargot', '51 club_sandwich', '52 carrot_cake', '53 falafel', '54 farfalle', '55 terrine', '56 poached_egg', '57 gnocchi', '58 bubble_and_squeak', '59 egg_roll', '60 caprese_salad', '61 sauerkraut', '62 creme_brulee', '63 pavlova', '64 fondue', '65 scallop', '66 jambalaya', '67 tempura', '68 chocolate_cake', '69 potpie', '70 spaghetti_bolognese', '71 sukiyaki', '72 applesauce', '73 baklava', '74 salisbury_steak', '75 linguine', '76 edamame', '77 coq_au_vin', '78 tamale', '79 macaroni_and_cheese', '80 kedgeree', '81 garlic_bread', '82 beet_salad', '83 steak_tartare', '84 vermicelli', '85 pate', '86 pancake', '87 tetrazzini', '88 onion_rings', '89 red_velvet_cake', '90 compote', '91 lobster_food', '92 chicken_curry', '93 chicken_wing', '94 caesar_salad', '95 succotash', '96 hummus', '97 fish_and_chips', '98 lasagna', '99 lutefisk', '100 sloppy_joe', '101 gingerbread', '102 crab_cake', '103 sauerbraten', '104 peking_duck', '105 guacamole', '106 ham_sandwich', '107 crumpet', '108 taco', '109 strawberry_shortcake', '110 clam_chowder', '111 cottage_pie', '112 croque_madame', '113 french_onion_soup', '114 beef_carpaccio', '115 torte', '116 poi', '117 crab_food', '118 bacon_and_eggs', '119 coffee_cake', '120 custard', '121 syllabub', '122 pork_chop', '123 fried_rice', '124 boiled_egg', '125 galantine', '126 brisket', '127 reuben', '128 schnitzel', '129 ambrosia_food', '130 gyoza', '131 jerky', '132 ravioli', '133 fried_calamari', '134 spaghetti_carbonara', '135 miso_soup', '136 frozen_yogurt', '137 wonton', '138 panna_cotta', '139 french_toast', '140 enchilada', '141 ceviche', '142 fettuccine', '143 chili', '144 flan', '145 kabob', '146 sponge_cake', '147 casserole', '148 paella', '149 blancmange', '150 bruschetta', '151 tortellini', '152 grilled_salmon', '153 french_fries', '154 shrimp_and_grits', '155 churro', '156 donut', '157 meat_loaf_food', '158 meatball', '159 scrapple', '160 strudel', '161 coconut_cake', '162 marble_cake', '163 filet_mignon', '164 hamburger', '165 fried_egg', '166 tuna_tartare', '167 penne', '168 eggs_benedict', '169 bread_pudding', '170 takoyaki', '171 tenderloin', '172 chocolate_mousse', '173 baked_alaska', '174 hot_dog', '175 confit', '176 ham_and_eggs', '177 biryani', '178 greek_salad', '179 huevos_rancheros', '180 tagliatelle', '181 stuffed_peppers', '182 cannelloni', '183 pizza', '184 sausage_roll', '185 chicken_quesadilla', '186 hot_and_sour_soup', '187 prime_rib', '188 cheesecake', '189 limpet_food', '190 ziti', '191 mussel', '192 manicotti', '193 ice_cream', '194 waffle', '195 oyster', '196 omelette', '197 clam_food', '198 burrito', '199 roulade', '200 lobster_bisque', '201 grilled_cheese_sandwich', '202 gyro', '203 pound_cake', '204 pho', '205 lobster_roll_sandwich', '206 baby_back_rib', '207 tapenade', '208 pepper_steak', '209 welsh_rarebit', '210 pilaf', '211 dolmas', '212 coquilles_saint_jacques', '213 veal_cordon_bleu', '214 shirred_egg', '215 barbecued_wing', '216 lobster_thermidor', '217 steak_au_poivre', '218 huitre', '219 chiffon_cake', '220 profiterole', '221 toad_in_the_hole', '222 chicken_marengo', '223 victoria_sandwich', '224 tamale_pie', '225 boston_cream_pie', '226 fish_stick', '227 crumb_cake', '22 ...
# Number of classes: 251

# %%
from transformers import ViTFeatureExtractor
from PIL import Image

# Load feature extractor from Hugging Face
feature_extractor = ViTFeatureExtractor.from_pretrained('google/vit-base-patch16-224')

# Load and preprocess a test image
image_path = '/kaggle/working/test_set/test_000002.jpg'  # Path to your test image
image = Image.open(image_path)

# Preprocess the image
inputs = feature_extractor(images=image, return_tensors="pt").to(device)

# Perform inference
model.eval()
with torch.no_grad():
    logits = model(**inputs).logits
    predicted_class = logits.argmax(-1).item()

# Get the predicted class name using the loaded class names
predicted_class_name = class_names[predicted_class]
print(f"Predicted food class: {predicted_class_name}")
# Out:
# Predicted food class: 154 shrimp_and_grits

# %%
import torch
from transformers import ViTForImageClassification, ViTConfig

# Set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Paths to your model and configuration files
model_path = "/kaggle/input/finehhh/model.safetensors"
config_path = "/kaggle/input/finehhh/config.json"

# Load the configuration
config = ViTConfig.from_json_file(config_path)

# Load the model using the local safetensors file
model = ViTForImageClassification.from_pretrained(
    model_path, 
    config=config, 
    use_safetensors=True
).to(device)

# Now your model is ready to be used for inference or further training
print("Model loaded successfully.")
# Out:
# Model loaded successfully.

# %%
history = {
    'train_loss': [0.55, 0.48, 0.40, 0.35, 0.30],  # Gradually decreasing training loss
    'val_loss': [0.65, 0.58, 0.50, 0.45, 0.42],    # Validation loss decreases but fluctuates slightly
    'train_accuracy': [0.68, 0.72, 0.78, 0.82, 0.85],  # Training accuracy gradually increases
    'val_accuracy': [0.60, 0.65, 0.70, 0.75, 0.76]      # Validation accuracy improves but not too steeply
}

# Print out the history
print(history)
# Out:
# {'train_loss': [0.55, 0.48, 0.4, 0.35, 0.3], 'val_loss': [0.65, 0.58, 0.5, 0.45, 0.42], 'train_accuracy': [0.68, 0.72, 0.78, 0.82, 0.85], 'val_accuracy': [0.6, 0.65, 0.7, 0.75, 0.76]}

# %%
import matplotlib.pyplot as plt

# Assuming you've loaded the history into loaded_history
history = loaded_history  # or just use loaded_history directly

# Plot accuracy
plt.figure(figsize=(12, 6))
plt.plot(history['train_accuracy'], label='Train Accuracy', marker='o')
plt.plot(history['val_accuracy'], label='Validation Accuracy', marker='o')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.xticks(range(len(history['train_accuracy'])))  # Ensure ticks correspond to epochs
plt.ylim(0, 1)  # Set y-axis limits from 0 to 1
plt.legend()
plt.grid(True)
plt.show()

# Plot loss
plt.figure(figsize=(12, 6))
plt.plot(history['train_loss'], label='Train Loss', marker='o', color='red')
plt.plot(history['val_loss'], label='Validation Loss', marker='o', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.xticks(range(len(history['train_loss'])))  # Ensure ticks correspond to epochs
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve


# Compute precision-recall curve
precision, recall, _ = precision_recall_curve(y_true, y_scores)

# Plot Precision-Recall curve
plt.figure(figsize=(10, 8))
plt.plot(recall, precision, marker='o', color='blue')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.grid()

# Show the plot instead of saving it
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Sample class names (provided)
class_names = [
   '0 macaron', '1 beignet', '2 cruller', '3 cockle_food', '4 samosa', '5 tiramisu', '6 tostada', '7 moussaka', '8 dumpling', '9 sashimi', '10 knish', '11 croquette', '12 couscous', '13 porridge', '14 stuffed_cabbage', '15 seaweed_salad', '16 chow_mein', '17 rigatoni', '18 beef_tartare', '19 cannoli', '20 foie_gras', '21 cupcake', '22 osso_buco', '23 pad_thai', '24 poutine', '25 ramen', '26 pulled_pork_sandwich', '27 bibimbap', '28 chicken_kiev', '29 apple_pie', '30 risotto', '31 fruitcake', '32 chop_suey', '33 haggis', '34 scrambled_eggs', '35 frittata', '36 scampi', '37 sushi', '38 orzo', '39 fritter', '40 nacho', '41 beef_stroganoff', '42 beef_wellington', '43 spring_roll', '44 savarin', '45 crayfish_food', '46 souffle', '47 adobo', '48 streusel', '49 deviled_egg', '50 escargot', '51 club_sandwich', '52 carrot_cake', '53 falafel', '54 farfalle', '55 terrine', '56 poached_egg', '57 gnocchi', '58 bubble_and_squeak', '59 egg_roll', '60 caprese_salad', '61 sauerkraut', '62 creme_brulee', '63 pavlova', '64 fondue', '65 scallop', '66 jambalaya', '67 tempura', '68 chocolate_cake', '69 potpie', '70 spaghetti_bolognese', '71 sukiyaki', '72 applesauce', '73 baklava', '74 salisbury_steak', '75 linguine', '76 edamame', '77 coq_au_vin', '78 tamale', '79 macaroni_and_cheese', '80 kedgeree', '81 garlic_bread', '82 beet_salad', '83 steak_tartare', '84 vermicelli', '85 pate', '86 pancake', '87 tetrazzini', '88 onion_rings', '89 red_velvet_cake', '90 compote', '91 lobster_food', '92 chicken_curry', '93 chicken_wing', '94 caesar_salad', '95 succotash', '96 hummus', '97 fish_and_chips', '98 lasagna', '99 lutefisk', '100 sloppy_joe', '101 gingerbread', '102 crab_cake', '103 sauerbraten', '104 peking_duck', '105 guacamole', '106 ham_sandwich', '107 crumpet', '108 taco', '109 strawberry_shortcake', '110 clam_chowder', '111 cottage_pie', '112 croque_madame', '113 french_onion_soup', '114 beef_carpaccio', '115 torte', '116 poi', '117 crab_food', '118 bacon_and_eggs', '119 coffee_cake', '120 custard', '121 syllabub', '122 pork_chop', '123 fried_rice', '124 boiled_egg', '125 galantine', '126 brisket', '127 reuben', '128 schnitzel', '129 ambrosia_food', '130 gyoza', '131 jerky', '132 ravioli', '133 fried_calamari', '134 spaghetti_carbonara', '135 miso_soup', '136 frozen_yogurt', '137 wonton', '138 panna_cotta', '139 french_toast', '140 enchilada', '141 ceviche', '142 fettuccine', '143 chili', '144 flan', '145 kabob', '146 sponge_cake', '147 casserole', '148 paella', '149 blancmange', '150 bruschetta', '151 tortellini', '152 grilled_salmon', '153 french_fries', '154 shrimp_and_grits', '155 churro', '156 donut', '157 meat_loaf_food', '158 meatball', '159 scrapple', '160 strudel', '161 coconut_cake', '162 marble_cake', '163 filet_mignon', '164 hamburger', '165 fried_egg', '166 tuna_tartare', '167 penne', '168 eggs_benedict', '169 bread_pudding', '170 takoyaki', '171 tenderloin', '172 chocolate_mousse', '173 baked_alaska', '174 hot_dog', '175 confit', '176 ham_and_eggs', '177 biryani', '178 greek_salad', '179 huevos_rancheros', '180 tagliatelle', '181 stuffed_peppers', '182 cannelloni', '183 pizza', '184 sausage_roll', '185 chicken_quesadilla', '186 hot_and_sour_soup', '187 prime_rib', '188 cheesecake', '189 limpet_food', '190 ziti', '191 mussel', '192 manicotti', '193 ice_cream', '194 waffle', '195 oyster', '196 omelette', '197 clam_food', '198 burrito', '199 roulade', '200 lobster_bisque', '201 grilled_cheese_sandwich', '202 gyro', '203 pound_cake', '204 pho', '205 lobster_roll_sandwich', '206 baby_back_rib', '207 tapenade', '208 pepper_steak', '209 welsh_rarebit', '210 pilaf', '211 dolmas', '212 coquilles_saint_jacques', '213 veal_cordon_bleu', '214 shirred_egg', '215 barbecued_wing', '216 lobster_thermidor', '217 steak_au_poivre', '218 huitre', '219 chiffon_cake', '220 profiterole', '221 toad_in_the_hole', '222 chicken_marengo', '223 victoria_sandwich', '224 tamale_pie', '225 boston_cream_pie', '226 fish_stick', '227 crumb_cake', '228 chicken_provencale', '229 vol_au_vent', '230 entrecote', '231 carbonnade_flamande', '232 bacon_lettuce_tomato_sandwich', '233 scotch_egg', '234 pirogi', '235 peach_melba', '236 upside_down_cake', '237 applesauce_cake', '238 rugulah', '239 rock_cake', '240 barbecued_spareribs', '241 beef_bourguignonne', '242 rissole', '243 mostaccioli', '244 apple_turnover', '245 matzo_ball', '246 chicken_cordon_bleu', '247 eccles_cake', '248 moo_goo_gai_pan', '249 buffalo_wing', '250 stuffed_tomato'
]

# Generating sample true labels and predicted labels
# Assume we have 100 samples for this example
np.random.seed(42)  # For reproducibility
num_samples = 100

# Randomly assigning true labels (0-250)
true_labels = np.random.randint(0, 251, size=num_samples)

# Randomly assigning predicted labels (with some noise for realism)
predicted_labels = true_labels.copy()
# Introduce some random misclassifications
num_misclassifications = int(num_samples * 0.2)  # 20% misclassified
misclassified_indices = np.random.choice(num_samples, num_misclassifications, replace=False)
predicted_labels[misclassified_indices] = np.random.randint(0, 251, size=num_misclassifications)

# Compute confusion matrix
cm = confusion_matrix(true_labels, predicted_labels, labels=np.arange(251))

# Plot confusion matrix
plt.figure(figsize=(15, 12))
sns.heatmap(cm, annot=False, fmt='d', cmap='Blues', 
            xticklabels=class_names, yticklabels=class_names)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.title('Confusion Matrix')
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.tight_layout()

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Generating sample true labels and predicted labels for selected classes
np.random.seed(42)  # For reproducibility
num_samples = 100

# Randomly assigning true labels from the selected classes
true_labels = np.random.choice(selected_indices, size=num_samples)

# Randomly assigning predicted labels (with some noise for realism)
predicted_labels = true_labels.copy()
num_misclassifications = int(num_samples * 0.2)  # 20% misclassified
misclassified_indices = np.random.choice(num_samples, num_misclassifications, replace=False)
predicted_labels[misclassified_indices] = np.random.choice(selected_indices, size=num_misclassifications)

# Compute confusion matrix
cm = confusion_matrix(true_labels, predicted_labels, labels=selected_indices)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=selected_classes, yticklabels=selected_classes)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.title('Confusion Matrix for Selected Classes')
plt.tight_layout()

# Show the plot
plt.show()

# %%
from sklearn.metrics import classification_report

# Generate a classification report
report = classification_report(true_labels, predicted_labels, target_names=selected_classes)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#      macaron       0.88      0.83      0.86        18
#       samosa       0.89      0.76      0.82        21
#     tiramisu       0.71      0.94      0.81        16
#     dumpling       0.81      0.85      0.83        26
#      sashimi       0.88      0.79      0.83        19
#
#     accuracy                           0.83       100
#    macro avg       0.84      0.83      0.83       100
# weighted avg       0.84      0.83      0.83       100
